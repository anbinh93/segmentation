# %%
# import os
# os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
# os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %%
# from tensorflow.python.client import device_lib

# def get_available_gpus():
#     local_device_protos = device_lib.list_local_devices()
#     return [x.name for x in local_device_protos if x.device_type == 'XLA_GPU']

# %%
# %pip install keras tensorflow
# Out:
# Collecting keras
#   Obtaining dependency information for keras from https://files.pythonhosted.org/packages/fc/a7/0d4490de967a67f68a538cc9cdb259bff971c4b5787f7765dc7c8f118f71/keras-2.15.0-py3-none-any.whl.metadata
#   Using cached keras-2.15.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting tensorflow
#   Obtaining dependency information for tensorflow from https://files.pythonhosted.org/packages/93/21/9b035a4f823d6aee2917c75415be9a95861ff3d73a0a65e48edbf210cec1/tensorflow-2.15.0-cp311-cp311-win_amd64.whl.metadata
#   Using cached tensorflow-2.15.0-cp311-cp311-win_amd64.whl.metadata (3.6 kB)
# Collecting tensorflow-intel==2.15.0 (from tensorflow)
#   Obtaining dependency information for tensorflow-intel==2.15.0 from https://files.pythonhosted.org/packages/4c/48/1a5a15517f18eaa4ff8d598b1c000300b20c1bb0e624539d702117a0c369/tensorflow_intel-2.15.0-cp311-cp311-win_amd64.whl.metadata
#   Using cached tensorflow_intel-2.15.0-cp311-cp311-win_amd64.whl.metadata (5.1 kB)
# Collecting absl-py>=1.0.0 (from tensorflow-intel==2.15.0->tensorflow)
#   Obtaining dependency information for absl-py>=1.0.0 from https://files.pythonhosted.org/packages/01/e4/dc0a1dcc4e74e08d7abedab278c795eef54a224363bb18f5692f416d834f/absl_py-2.0.0-py3-none-any.whl.metadata
#   Using cached absl_py-2.0.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting astunparse>=1.6.0 (from tensorflow-intel==2.15.0->tensorflow)
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting flatbuffers>=23.5.26 (from tensorflow-intel==2.15.0->tensorflow)
#   Obtaining dependency information for flatbuffers>=23.5.26 from https://files.pythonhosted.org/packages/6f/12/d5c79ee252793ffe845d58a913197bfa02ae9a0b5c9bc3dc4b58d477b9e7/flatbuffers-23.5.26-py2.py3-none-any.whl.metadata
#   Using cached flatbuffers-23.5.26-py2.py3-none-any.whl.metadata (850 bytes)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 (from tensorflow-intel==2.15.0->tensorflow)
#   Using cached gast-0.5.4-py3-none-any.whl (19 kB)
# Collecting google-pasta>=0.1.1 (from tensorflow-intel==2.15.0->tensorflow)
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Collecting h5py>=2.9.0 (from tensorflow-intel==2.15.0->tensorflow)
#   Obtaining dependency information for h5py>=2.9.0 from https://files.pythonhosted.org/packages/b6/35/ed21094eb4d8acf31ccc7666a4d8701c1ce38f8d1fa3c7036f24416f6337/h5py-3.10.0-cp311-cp311-win_amd64.whl.metadata
#   Downloading h5py-3.10.0-cp311-cp311-win_amd64.whl.metadata (2.5 kB)
# Collecting libclang>=13.0.0 (from tensorflow-intel==2.15.0->tensorflow)
#   Obtaining dependency information for libclang>=13.0.0 from https://files.pythonhosted.org/packages/02/8c/dc970bc00867fe290e8c8a7befa1635af716a9ebdfe3fb9dce0ca4b522ce/libclang-16.0.6-py2.py3-none-win_amd64.whl.metadata
#   Using cached libclang-16.0.6-py2.py3-none-win_amd64.whl.metadata (5.3 kB)
# Collecting ml-dtypes~=0.2.0 (from tensorflow-intel==2.15.0->tensorflow)
#   Obtaining dependency information for ml-dtypes~=0.2.0 from https://files.pythonhosted.org/packages/08/89/c727fde1a3d12586e0b8c01abf53754707d76beaa9987640e70807d4545f/ml_dtypes-0.2.0-cp311-cp311-win_amd64.whl.metadata
#   Using cached ml_dtypes-0.2.0-cp311-cp311-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.26.0)
# Collecting opt-einsum>=2.3.2 (from tensorflow-intel==2.15.0->tensorflow)
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Requirement already satisfied: packaging in c:\users\dell\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.15.0->tensorflow) (23.1)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 (from tensorflow-intel==2.15.0->tensorflow)
#   Obtaining dependency information for protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 from https://files.pythonhosted.org/packages/fe/6b/7f177e8d6fe4caa14f4065433af9f879d4fab84f0d17dcba7b407f6bd808/protobuf-4.25.1-cp310-abi3-win_amd64.whl.metadata
#   Using cached protobuf-4.25.1-cp310-abi3-win_amd64.whl.metadata (541 bytes)
# Requirement already satisfied: setuptools in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (65.5.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\dell\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.16.0)
# Collecting termcolor>=1.1.0 (from tensorflow-intel==2.15.0->tensorflow)
#   Using cached termcolor-2.3.0-py3-none-any.whl (6.9 kB)
# Collecting typing-extensions>=3.6.6 (from tensorflow-intel==2.15.0->tensorflow)
#   Obtaining dependency information for typing-extensions>=3.6.6 from https://files.pythonhosted.org/packages/24/21/7d397a4b7934ff4028987914ac1044d3b7d52712f30e2ac7a2ae5bc86dd0/typing_extensions-4.8.0-py3-none-any.whl.metadata
#   Downloading typing_extensions-4.8.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting wrapt<1.15,>=1.11.0 (from tensorflow-intel==2.15.0->tensorflow)
#   Obtaining dependency information for wrapt<1.15,>=1.11.0 from https://files.pythonhosted.org/packages/ba/7e/14113996bc6ee68eb987773b4139c87afd3ceff60e27e37648aa5eb2798a/wrapt-1.14.1-cp311-cp311-win_amd64.whl.metadata
#   Downloading wrapt-1.14.1-cp311-cp311-win_amd64.whl.metadata (6.9 kB)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1 (from tensorflow-intel==2.15.0->tensorflow)
#   Using cached tensorflow_io_gcs_filesystem-0.31.0-cp311-cp311-win_amd64.whl (1.5 MB)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow-intel==2.15.0->tensorflow)
#   Obtaining dependency information for grpcio<2.0,>=1.24.3 from https://files.pythonhosted.org/packages/bc/e5/f656b17fe1ccda1e2a4fe20298b8bcf7c804561c90ee763e39efc1c3772f/grpcio-1.59.3-cp311-cp311-win_amd64.whl.metadata
#   Using cached grpcio-1.59.3-cp311-cp311-win_amd64.whl.metadata (4.2 kB)
# Collecting tensorboard<2.16,>=2.15 (from tensorflow-intel==2.15.0->tensorflow)
#   Obtaining dependency information for tensorboard<2.16,>=2.15 from https://files.pythonhosted.org/packages/6e/0c/1059a6682cf2cc1fcc0d5327837b5672fe4f5574255fa5430d0a8ceb75e9/tensorboard-2.15.1-py3-none-any.whl.metadata
#   Using cached tensorboard-2.15.1-py3-none-any.whl.metadata (1.7 kB)
# Collecting tensorflow-estimator<2.16,>=2.15.0 (from tensorflow-intel==2.15.0->tensorflow)
#   Obtaining dependency information for tensorflow-estimator<2.16,>=2.15.0 from https://files.pythonhosted.org/packages/b6/c8/2f823c8958d5342eafc6dd3e922f0cc4fcf8c2e0460284cc462dae3b60a0/tensorflow_estimator-2.15.0-py2.py3-none-any.whl.metadata
#   Using cached tensorflow_estimator-2.15.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting wheel<1.0,>=0.23.0 (from astunparse>=1.6.0->tensorflow-intel==2.15.0->tensorflow)
#   Obtaining dependency information for wheel<1.0,>=0.23.0 from https://files.pythonhosted.org/packages/fa/7f/4c07234086edbce4a0a446209dc0cb08a19bb206a3ea53b2f56a403f983b/wheel-0.41.3-py3-none-any.whl.metadata
#   Downloading wheel-0.41.3-py3-none-any.whl.metadata (2.2 kB)
# Collecting google-auth<3,>=1.6.3 (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow)
#   Obtaining dependency information for google-auth<3,>=1.6.3 from https://files.pythonhosted.org/packages/86/a7/75911c13a242735d5aeaca6a272da380335ff4ba5f26d6b2ae20ff682d13/google_auth-2.23.4-py2.py3-none-any.whl.metadata
#   Using cached google_auth-2.23.4-py2.py3-none-any.whl.metadata (4.7 kB)
# Collecting google-auth-oauthlib<2,>=0.5 (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow)
#   Obtaining dependency information for google-auth-oauthlib<2,>=0.5 from https://files.pythonhosted.org/packages/ce/33/a907b4b67245647746dde8d61e1643ef5d210c88e090d491efd89eff9f95/google_auth_oauthlib-1.1.0-py2.py3-none-any.whl.metadata
#   Using cached google_auth_oauthlib-1.1.0-py2.py3-none-any.whl.metadata (2.7 kB)
# Collecting markdown>=2.6.8 (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow)
#   Obtaining dependency information for markdown>=2.6.8 from https://files.pythonhosted.org/packages/70/58/2c5a654173937d9f540a4971c569b44dcd55e5424a484d954cdaeebcf79c/Markdown-3.5.1-py3-none-any.whl.metadata
#   Downloading Markdown-3.5.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 (from tensorflow-intel==2.15.0->tensorflow)
#   Obtaining dependency information for protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 from https://files.pythonhosted.org/packages/80/70/dc63d340d27b8ff22022d7dd14b8d6d68b479a003eacdc4507150a286d9a/protobuf-4.23.4-cp310-abi3-win_amd64.whl.metadata
#   Using cached protobuf-4.23.4-cp310-abi3-win_amd64.whl.metadata (540 bytes)
# Collecting requests<3,>=2.21.0 (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow)
#   Obtaining dependency information for requests<3,>=2.21.0 from https://files.pythonhosted.org/packages/70/8e/0e2d847013cb52cd35b38c009bb167a1a26b2ce6cd6965bf26b47bc0bf44/requests-2.31.0-py3-none-any.whl.metadata
#   Using cached requests-2.31.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow)
#   Obtaining dependency information for tensorboard-data-server<0.8.0,>=0.7.0 from https://files.pythonhosted.org/packages/7a/13/e503968fefabd4c6b2650af21e110aa8466fe21432cd7c43a84577a89438/tensorboard_data_server-0.7.2-py3-none-any.whl.metadata
#   Using cached tensorboard_data_server-0.7.2-py3-none-any.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow)
#   Obtaining dependency information for werkzeug>=1.0.1 from https://files.pythonhosted.org/packages/c3/fc/254c3e9b5feb89ff5b9076a23218dafbc99c96ac5941e900b71206e6313b/werkzeug-3.0.1-py3-none-any.whl.metadata
#   Downloading werkzeug-3.0.1-py3-none-any.whl.metadata (4.1 kB)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow)
#   Obtaining dependency information for cachetools<6.0,>=2.0.0 from https://files.pythonhosted.org/packages/a2/91/2d843adb9fbd911e0da45fbf6f18ca89d07a087c3daa23e955584f90ebf4/cachetools-5.3.2-py3-none-any.whl.metadata
#   Using cached cachetools-5.3.2-py3-none-any.whl.metadata (5.2 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow)
#   Downloading pyasn1_modules-0.3.0-py2.py3-none-any.whl (181 kB)
#      ---------------------------------------- 0.0/181.3 kB ? eta -:--:--
#      ------ -------------------------------- 30.7/181.3 kB 1.3 MB/s eta 0:00:01
#      ------ -------------------------------- 30.7/181.3 kB 1.3 MB/s eta 0:00:01
#      ------ -------------------------------- 30.7/181.3 kB 1.3 MB/s eta 0:00:01
#      ------ -------------------------------- 30.7/181.3 kB 1.3 MB/s eta 0:00:01
#      ------------ ------------------------ 61.4/181.3 kB 233.8 kB/s eta 0:00:01
#      ---------------- -------------------- 81.9/181.3 kB 286.7 kB/s eta 0:00:01
#      ---------------------- ------------- 112.6/181.3 kB 344.8 kB/s eta 0:00:01
#      ---------------------- ------------- 112.6/181.3 kB 344.8 kB/s eta 0:00:01
#      ---------------------------- ------- 143.4/181.3 kB 340.5 kB/s eta 0:00:01
#      ------------------------------------ 181.3/181.3 kB 390.6 kB/s eta 0:00:00
# Collecting rsa<5,>=3.1.4 (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow)
#   Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Collecting requests-oauthlib>=0.7.0 (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow)
#   Using cached requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Collecting charset-normalizer<4,>=2 (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow)
#   Obtaining dependency information for charset-normalizer<4,>=2 from https://files.pythonhosted.org/packages/57/ec/80c8d48ac8b1741d5b963797b7c0c869335619e13d4744ca2f67fc11c6fc/charset_normalizer-3.3.2-cp311-cp311-win_amd64.whl.metadata
#   Downloading charset_normalizer-3.3.2-cp311-cp311-win_amd64.whl.metadata (34 kB)
# Collecting idna<4,>=2.5 (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow)
#   Obtaining dependency information for idna<4,>=2.5 from https://files.pythonhosted.org/packages/ea/65/9c7a31be86861d43da3d4f8661f677b38120320540773a04979ad6fa9ecd/idna-3.5-py3-none-any.whl.metadata
#   Downloading idna-3.5-py3-none-any.whl.metadata (9.9 kB)
# Collecting urllib3<3,>=1.21.1 (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow)
#   Obtaining dependency information for urllib3<3,>=1.21.1 from https://files.pythonhosted.org/packages/96/94/c31f58c7a7f470d5665935262ebd7455c7e4c7782eb525658d3dbf4b9403/urllib3-2.1.0-py3-none-any.whl.metadata
#   Downloading urllib3-2.1.0-py3-none-any.whl.metadata (6.4 kB)
# Collecting certifi>=2017.4.17 (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow)
#   Obtaining dependency information for certifi>=2017.4.17 from https://files.pythonhosted.org/packages/64/62/428ef076be88fa93716b576e4a01f919d25968913e817077a386fcbe4f42/certifi-2023.11.17-py3-none-any.whl.metadata
#   Downloading certifi-2023.11.17-py3-none-any.whl.metadata (2.2 kB)
# Collecting MarkupSafe>=2.1.1 (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow)
#   Obtaining dependency information for MarkupSafe>=2.1.1 from https://files.pythonhosted.org/packages/be/bb/08b85bc194034efbf572e70c3951549c8eca0ada25363afc154386b5390a/MarkupSafe-2.1.3-cp311-cp311-win_amd64.whl.metadata
#   Using cached MarkupSafe-2.1.3-cp311-cp311-win_amd64.whl.metadata (3.1 kB)
# Collecting pyasn1<0.6.0,>=0.4.6 (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow)
#   Obtaining dependency information for pyasn1<0.6.0,>=0.4.6 from https://files.pythonhosted.org/packages/d1/75/4686d2872bf2fc0b37917cbc8bbf0dd3a5cdb0990799be1b9cbf1e1eb733/pyasn1-0.5.1-py2.py3-none-any.whl.metadata
#   Downloading pyasn1-0.5.1-py2.py3-none-any.whl.metadata (8.6 kB)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow)
#   Using cached oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Using cached keras-2.15.0-py3-none-any.whl (1.7 MB)
# Using cached tensorflow-2.15.0-cp311-cp311-win_amd64.whl (2.1 kB)
# Using cached tensorflow_intel-2.15.0-cp311-cp311-win_amd64.whl (300.9 MB)
# Using cached absl_py-2.0.0-py3-none-any.whl (130 kB)
# Using cached flatbuffers-23.5.26-py2.py3-none-any.whl (26 kB)
# Using cached grpcio-1.59.3-cp311-cp311-win_amd64.whl (3.7 MB)
# Downloading h5py-3.10.0-cp311-cp311-win_amd64.whl (2.7 MB)
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    - -------------------------------------- 0.1/2.7 MB 7.0 MB/s eta 0:00:01
#    - -------------------------------------- 0.1/2.7 MB 7.0 MB/s eta 0:00:01
#    - -------------------------------------- 0.1/2.7 MB 7.0 MB/s eta 0:00:01
#    - -------------------------------------- 0.1/2.7 MB 7.0 MB/s eta 0:00:01
#    --- ------------------------------------ 0.2/2.7 MB 1.0 MB/s eta 0:00:03
#    ----- ---------------------------------- 0.4/2.7 MB 1.3 MB/s eta 0:00:02
#    ----- ---------------------------------- 0.4/2.7 MB 1.3 MB/s eta 0:00:02
#    ----- ---------------------------------- 0.4/2.7 MB 1.3 MB/s eta 0:00:02
#    -------- ------------------------------- 0.5/2.7 MB 1.3 MB/s eta 0:00:02
#    ----------- ---------------------------- 0.8/2.7 MB 1.7 MB/s eta 0:00:02
#    ------------- -------------------------- 0.9/2.7 MB 1.8 MB/s eta 0:00:01
#    -------------- ------------------------- 1.0/2.7 MB 1.7 MB/s eta 0:00:02
#    ------------------ --------------------- 1.2/2.7 MB 2.0 MB/s eta 0:00:01
#    ------------------------- -------------- 1.7/2.7 MB 2.6 MB/s eta 0:00:01
#    ----------------------------- ---------- 2.0/2.7 MB 2.9 MB/s eta 0:00:01
#    ------------------------------- -------- 2.1/2.7 MB 2.8 MB/s eta 0:00:01
#    ---------------------------------------  2.6/2.7 MB 3.3 MB/s eta 0:00:01
#    ---------------------------------------- 2.7/2.7 MB 3.3 MB/s eta 0:00:00
# Using cached libclang-16.0.6-py2.py3-none-win_amd64.whl (24.4 MB)
# Using cached ml_dtypes-0.2.0-cp311-cp311-win_amd64.whl (938 kB)
# Using cached tensorboard-2.15.1-py3-none-any.whl (5.5 MB)
# Using cached protobuf-4.23.4-cp310-abi3-win_amd64.whl (422 kB)
# Using cached tensorflow_estimator-2.15.0-py2.py3-none-any.whl (441 kB)
# Downloading typing_extensions-4.8.0-py3-none-any.whl (31 kB)
# Downloading wrapt-1.14.1-cp311-cp311-win_amd64.whl (35 kB)
# Using cached google_auth-2.23.4-py2.py3-none-any.whl (183 kB)
# Using cached google_auth_oauthlib-1.1.0-py2.py3-none-any.whl (19 kB)
# Downloading Markdown-3.5.1-py3-none-any.whl (102 kB)
#    ---------------------------------------- 0.0/102.2 kB ? eta -:--:--
#    -------------------------------- ------- 81.9/102.2 kB ? eta -:--:--
#    -------------------------------- ------- 81.9/102.2 kB ? eta -:--:--
#    -------------------------------- ------- 81.9/102.2 kB ? eta -:--:--
#    -------------------------------- ------- 81.9/102.2 kB ? eta -:--:--
#    -------------------------------- ------- 81.9/102.2 kB ? eta -:--:--
#    -------------------------------- ------- 81.9/102.2 kB ? eta -:--:--
#    -------------------------------- ------- 81.9/102.2 kB ? eta -:--:--
#    -------------------------------- ------- 81.9/102.2 kB ? eta -:--:--
#    -------------------------------- ------- 81.9/102.2 kB ? eta -:--:--
#    -------------------------------- ------- 81.9/102.2 kB ? eta -:--:--
#    -------------------------------- ------- 81.9/102.2 kB ? eta -:--:--
#    -------------------------------- ------- 81.9/102.2 kB ? eta -:--:--
#    -------------------------------- ------- 81.9/102.2 kB ? eta -:--:--
#    -------------------------------- ------- 81.9/102.2 kB ? eta -:--:--
#    -------------------------------- ------- 81.9/102.2 kB ? eta -:--:--
#    -------------------------------- ------- 81.9/102.2 kB ? eta -:--:--
#    -------------------------------- ------- 81.9/102.2 kB ? eta -:--:--
#    -------------------------------- ------- 81.9/102.2 kB ? eta -:--:--
#    -------------------------------- ------- 81.9/102.2 kB ? eta -:--:--
#    -------------------------------- ------- 81.9/102.2 kB ? eta -:--:--
#    -------------------------------- ------- 81.9/102.2 kB ? eta -:--:--
#    -------------------------------- ------- 81.9/102.2 kB ? eta -:--:--
#    -------------------------------- ------- 81.9/102.2 kB ? eta -:--:--
#    -------------------------------- ------- 81.9/102.2 kB ? eta -:--:--
#    -------------------------------- ------- 81.9/102.2 kB ? eta -:--:--
#    -------------------------------- ------- 81.9/102.2 kB ? eta -:--:--
#    -------------------------------- ------- 81.9/102.2 kB ? eta -:--:--
#    -------------------------------- ------- 81.9/102.2 kB ? eta -:--:--
#    -------------------------------- ------- 81.9/102.2 kB ? eta -:--:--
#    -------------------------------- ------- 81.9/102.2 kB ? eta -:--:--
#    ------------------------------------ --- 92.2/102.2 kB 57.6 kB/s eta 0:00:01
#    --------------------------------------- 102.2/102.2 kB 64.0 kB/s eta 0:00:00
# Using cached requests-2.31.0-py3-none-any.whl (62 kB)
# Using cached tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Downloading werkzeug-3.0.1-py3-none-any.whl (226 kB)
#    ---------------------------------------- 0.0/226.7 kB ? eta -:--:--
#    ---------------------------------------- 226.7/226.7 kB ? eta 0:00:00
# Downloading wheel-0.41.3-py3-none-any.whl (65 kB)
#    ---------------------------------------- 0.0/65.8 kB ? eta -:--:--
#    ---------------------------------------- 65.8/65.8 kB ? eta 0:00:00
# Using cached cachetools-5.3.2-py3-none-any.whl (9.3 kB)
# Downloading certifi-2023.11.17-py3-none-any.whl (162 kB)
#    ---------------------------------------- 0.0/162.5 kB ? eta -:--:--
#    --------------------------------------- 162.5/162.5 kB 10.2 MB/s eta 0:00:00
# Downloading charset_normalizer-3.3.2-cp311-cp311-win_amd64.whl (99 kB)
#    ---------------------------------------- 0.0/99.9 kB ? eta -:--:--
#    ---------------------------------------- 99.9/99.9 kB ? eta 0:00:00
# Downloading idna-3.5-py3-none-any.whl (61 kB)
#    ---------------------------------------- 0.0/61.6 kB ? eta -:--:--
#    ---------------------------------------- 61.6/61.6 kB 3.2 MB/s eta 0:00:00
# Using cached MarkupSafe-2.1.3-cp311-cp311-win_amd64.whl (17 kB)
# Downloading urllib3-2.1.0-py3-none-any.whl (104 kB)
#    ---------------------------------------- 0.0/104.6 kB ? eta -:--:--
#    ---------------------------------------- 104.6/104.6 kB 5.9 MB/s eta 0:00:00
# Downloading pyasn1-0.5.1-py2.py3-none-any.whl (84 kB)
#    ---------------------------------------- 0.0/84.9 kB ? eta -:--:--
#    ---------------------------------------- 84.9/84.9 kB 2.4 MB/s eta 0:00:00
# Installing collected packages: libclang, flatbuffers, wrapt, wheel, urllib3, typing-extensions, termcolor, tensorflow-io-gcs-filesystem, tensorflow-estimator, tensorboard-data-server, pyasn1, protobuf, opt-einsum, oauthlib, ml-dtypes, MarkupSafe, markdown, keras, idna, h5py, grpcio, google-pasta, gast, charset-normalizer, certifi, cachetools, absl-py, werkzeug, rsa, requests, pyasn1-modules, astunparse, requests-oauthlib, google-auth, google-auth-oauthlib, tensorboard, tensorflow-intel, tensorflow
# Successfully installed MarkupSafe-2.1.3 absl-py-2.0.0 astunparse-1.6.3 cachetools-5.3.2 certifi-2023.11.17 charset-normalizer-3.3.2 flatbuffers-23.5.26 gast-0.5.4 google-auth-2.23.4 google-auth-oauthlib-1.1.0 google-pasta-0.2.0 grpcio-1.59.3 h5py-3.10.0 idna-3.5 keras-2.15.0 libclang-16.0.6 markdown-3.5.1 ml-dtypes-0.2.0 oauthlib-3.2.2 opt-einsum-3.3.0 protobuf-4.23.4 pyasn1-0.5.1 pyasn1-modules-0.3.0 requests-2.31.0 requests-oauthlib-1.3.1 rsa-4.9 tensorboard-2.15.1 tensorboard-data-server-0.7.2 tensorflow-2.15.0 tensorflow-estimator-2.15.0 tensorflow-intel-2.15.0 tensorflow-io-gcs-filesystem-0.31.0 termcolor-2.3.0 typing-extensions-4.8.0 urllib3-2.1.0 werkzeug-3.0.1 wheel-0.41.3 wrapt-1.14.1
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script wheel.exe is installed in 'c:\Users\Dell\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script markdown_py.exe is installed in 'c:\Users\Dell\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script normalizer.exe is installed in 'c:\Users\Dell\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts pyrsa-decrypt.exe, pyrsa-encrypt.exe, pyrsa-keygen.exe, pyrsa-priv2pub.exe, pyrsa-sign.exe and pyrsa-verify.exe are installed in 'c:\Users\Dell\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script google-oauthlib-tool.exe is installed in 'c:\Users\Dell\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script tensorboard.exe is installed in 'c:\Users\Dell\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts estimator_ckpt_converter.exe, import_pb_to_tensorboard.exe, saved_model_cli.exe, tensorboard.exe, tf_upgrade_v2.exe, tflite_convert.exe, toco.exe and toco_from_protos.exe are installed in 'c:\Users\Dell\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
import sys
import warnings
warnings.filterwarnings("ignore")

import numpy as np
from keras.layers import (
    Conv2D, BatchNormalization, Dense, 
    ZeroPadding2D, Activation, GlobalAveragePooling2D,
    Reshape, Permute, multiply, AveragePooling2D,
    UpSampling2D, Concatenate, Add, Lambda, Multiply
)
from keras.models import Model, Sequential
from keras.layers import Input
import keras.backend as K
from keras.layers import DepthwiseConv2D, PReLU
# Out:
# WARNING:tensorflow:From c:\Users\Dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (4.8.1.78)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from opencv-python) (1.26.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import cv2
# import imutils

# %%
# !pip install imgaug
# Out:
# Collecting imgaug
#   Downloading imgaug-0.4.0-py2.py3-none-any.whl (948 kB)
#      ---------------------------------------- 0.0/948.0 kB ? eta -:--:--
#      ---------------------------------------- 10.2/948.0 kB ? eta -:--:--
#      - ----------------------------------- 30.7/948.0 kB 435.7 kB/s eta 0:00:03
#      - ----------------------------------- 30.7/948.0 kB 435.7 kB/s eta 0:00:03
#      - ----------------------------------- 30.7/948.0 kB 435.7 kB/s eta 0:00:03
#      -- ---------------------------------- 61.4/948.0 kB 252.2 kB/s eta 0:00:04
#      ---- ------------------------------- 112.6/948.0 kB 385.0 kB/s eta 0:00:03
#      ---- ------------------------------- 112.6/948.0 kB 385.0 kB/s eta 0:00:03
#      ---- ------------------------------- 122.9/948.0 kB 312.9 kB/s eta 0:00:03
#      ------ ----------------------------- 174.1/948.0 kB 403.5 kB/s eta 0:00:02
#      -------- --------------------------- 235.5/948.0 kB 497.3 kB/s eta 0:00:02
#      -------- --------------------------- 235.5/948.0 kB 497.3 kB/s eta 0:00:02
#      --------- -------------------------- 256.0/948.0 kB 449.3 kB/s eta 0:00:02
#      ------------ ----------------------- 317.4/948.0 kB 517.2 kB/s eta 0:00:02
#      ------------- ---------------------- 368.6/948.0 kB 573.4 kB/s eta 0:00:02
#      ------------- ---------------------- 368.6/948.0 kB 573.4 kB/s eta 0:00:02
#      --------------- -------------------- 399.4/948.0 kB 541.2 kB/s eta 0:00:02
#      ------------------ ----------------- 481.3/948.0 kB 603.1 kB/s eta 0:00:01
#      ----------------------- ------------ 624.6/948.0 kB 742.0 kB/s eta 0:00:01
#      ------------------------ ----------- 645.1/948.0 kB 766.8 kB/s eta 0:00:01
#      --------------------------- -------- 716.8/948.0 kB 766.3 kB/s eta 0:00:01
#      ---------------------------------- - 911.4/948.0 kB 929.9 kB/s eta 0:00:01
#      ------------------------------------ 948.0/948.0 kB 952.1 kB/s eta 0:00:00
# Requirement already satisfied: six in c:\users\dell\appdata\roaming\python\python311\site-packages (from imgaug) (1.16.0)
# Requirement already satisfied: numpy>=1.15 in c:\users\dell\anaconda3\lib\site-packages (from imgaug) (1.24.3)
# Requirement already satisfied: scipy in c:\users\dell\anaconda3\lib\site-packages (from imgaug) (1.10.1)
# Requirement already satisfied: Pillow in c:\users\dell\anaconda3\lib\site-packages (from imgaug) (9.4.0)
# Requirement already satisfied: matplotlib in c:\users\dell\anaconda3\lib\site-packages (from imgaug) (3.7.1)
# Requirement already satisfied: scikit-image>=0.14.2 in c:\users\dell\anaconda3\lib\site-packages (from imgaug) (0.20.0)
# Requirement already satisfied: opencv-python in c:\users\dell\anaconda3\lib\site-packages (from imgaug) (4.8.1.78)
# Requirement already satisfied: imageio in c:\users\dell\anaconda3\lib\site-packages (from imgaug) (2.26.0)
# Requirement already satisfied: Shapely in c:\users\dell\anaconda3\lib\site-packages (from imgaug) (2.0.2)
# Requirement already satisfied: networkx>=2.8 in c:\users\dell\anaconda3\lib\site-packages (from scikit-image>=0.14.2->imgaug) (3.1)
# Requirement already satisfied: tifffile>=2019.7.26 in c:\users\dell\anaconda3\lib\site-packages (from scikit-image>=0.14.2->imgaug) (2021.7.2)
# Requirement already satisfied: PyWavelets>=1.1.1 in c:\users\dell\anaconda3\lib\site-packages (from scikit-image>=0.14.2->imgaug) (1.4.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\dell\appdata\roaming\python\python311\site-packages (from scikit-image>=0.14.2->imgaug) (23.1)
# Requirement already satisfied: lazy_loader>=0.1 in c:\users\dell\anaconda3\lib\site-packages (from scikit-image>=0.14.2->imgaug) (0.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dell\anaconda3\lib\site-packages (from matplotlib->imgaug) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\dell\anaconda3\lib\site-packages (from matplotlib->imgaug) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dell\anaconda3\lib\site-packages (from matplotlib->imgaug) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\dell\anaconda3\lib\site-packages (from matplotlib->imgaug) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\dell\anaconda3\lib\site-packages (from matplotlib->imgaug) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dell\appdata\roaming\python\python311\site-packages (from matplotlib->imgaug) (2.8.2)
# Installing collected packages: imgaug
# Successfully installed imgaug-0.4.0

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\dell\anaconda3\lib\site-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\dell\appdata\roaming\python\python311\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dell\anaconda3\lib\site-packages (from pandas) (2022.7)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\dell\anaconda3\lib\site-packages (from pandas) (1.24.3)
# Requirement already satisfied: six>=1.5 in c:\users\dell\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
from glob import glob
import pandas as pd
from sklearn.utils import shuffle
import imgaug as ia
from imgaug import augmenters as iaa
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# d:\Code\Machine Learning\workspace\workspace\sinet-segmentation.ipynb Cell 9 line 2
#       <a href='vscode-notebook-cell:/d%3A/Code/Machine%20Learning/workspace/workspace/sinet-segmentation.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> from glob import glob
# ----> <a href='vscode-notebook-cell:/d%3A/Code/Machine%20Learning/workspace/workspace/sinet-segmentation.ipynb#X10sZmlsZQ%3D%3D?line=1'>2</a> import pandas as pd
#       <a href='vscode-notebook-cell:/d%3A/Code/Machine%20Learning/workspace/workspace/sinet-segmentation.ipynb#X10sZmlsZQ%3D%3D?line=2'>3</a> from sklearn.utils import shuffle
#       <a href='vscode-notebook-cell:/d%3A/Code/Machine%20Learning/workspace/workspace/sinet-segmentation.ipynb#X10sZmlsZQ%3D%3D?line=3'>4</a> import imgaug as ia
#
# ModuleNotFoundError: No module named 'pandas'

# %%
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, BaseLogger
from imgaug.augmentables.segmaps import SegmentationMapsOnImage

# %%
from keras import __version__
print(__version__)
# Out:
# 2.9.0

# %%
import tensorflow as tf
tf.__version__
tf.config.list_logical_devices()
# Out:
# 2023-11-25 06:26:33.964973: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# [LogicalDevice(name='/device:CPU:0', device_type='CPU')]

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 12793046039434655761
# xla_global_id: -1
# ]

# %%
tf.test.is_gpu_available()
# Out:
# False

# %% [markdown]
# ## Constant Variables

# %%
IMG_HEIGHT = 224
IMG_WIDTH = 224
IMG_CHANNEL = 3
CLASSES = ["Background", "Person"]
N_CLASSES = 2
IMAGE_DATA_FORMAT = K.image_data_format()

# %% [markdown]
# ## Building model

# %%
from keras.regularizers import l2
from keras.utils import plot_model

# %%
class SiNet:
    def __init__(self, img_height, img_width, img_channel, n_classes, reg=1e-4):
        self.img_height = img_height
        self.img_width = img_width
        self.img_channel = img_channel
        self.n_classes = n_classes
        self.reg = reg
        self.channel_axis = 1 if K.image_data_format() == "channels_first" else -1
        self.alpha = 1.0
        self.image_val = 0.017
        self.mean_substraction = [103.94, 116.78, 123.68]
        
    def relu6(self, x):
        return K.relu(x, max_value=6)
    
    def _conv_block(self, inputs, filters, alpha, strides=(1,1), kernel=(3,3), block_id=1, padding="valid"):
        """"""
        filters = int(filters * alpha)
        
        if padding=="same":
            x = inputs
        else:
            x = ZeroPadding2D((1, 1), data_format=IMAGE_DATA_FORMAT, 
                              name="conv_%s_pad" % block_id)(inputs)        
        
        x = Conv2D(filters, kernel, data_format=IMAGE_DATA_FORMAT, 
                   padding=padding, use_bias=False, strides=strides, 
                   kernel_initializer="he_normal", kernel_regularizer=l2(self.reg), 
                   name="conv_%s" % block_id)(x)
        x = BatchNormalization(axis=self.channel_axis, name="conv_%s_bn" % block_id)(x)
        x = Activation("relu", name="conv_%s_act" % block_id)(x)
        
        return x
    
    def _pointwise_conv_block(self, inputs, pointwise_conv_filters, alpha, 
                              strides=(1, 1), block_id=1):
        x = Conv2D(pointwise_conv_filters, 
                   (1, 1),
                   data_format=IMAGE_DATA_FORMAT,
                   padding="same",
                   use_bias=False,
                   strides=(1, 1),
                   kernel_initializer="he_normal",
                   kernel_regularizer=l2(self.reg),
                   name="conv_pw_%s" % block_id)(inputs)
        x = BatchNormalization(axis=self.channel_axis,
                               name="conv_pw_%s_bn" % block_id)(x)
        x = Activation("relu", name="conv_pw_%s_relu" % block_id)(x)
        
        return x
        
    def _depthwise_conv_block(self, inputs, pointwise_conv_filters, alpha, 
                              depth_multiplier=1, strides=(1, 1), block_id=1, 
                              kernel=(3,3), padding_size=(1, 1)):
        """"""
        pointwise_conv_filters = int(pointwise_conv_filters * alpha)
        
        x = ZeroPadding2D(padding_size, 
                          data_format=IMAGE_DATA_FORMAT,
                          name="conv_pad_%s" % block_id)(inputs)
        x = DepthwiseConv2D(kernel_size=kernel,
                            data_format=IMAGE_DATA_FORMAT,
                            depth_multiplier=depth_multiplier,
                            strides=strides,
                            use_bias=False,
                            depthwise_regularizer=l2(self.reg),
                            name="conv_dw_%s" % block_id)(x)
        x = BatchNormalization(axis=self.channel_axis,
                               name="conv_dw_%s_bn" % block_id)(x)
#         x = Activation("PReLu", name="conv_dw_%d_Prelu" % block_id)(x)
        x = PReLU(name="conv_dw_%s_Prelu" % block_id)(x)
        
        x = self._pointwise_conv_block(x, pointwise_conv_filters, self.alpha, block_id=block_id)
        
        return x
    
    def _squeeze_excite_block(self, inputs, ratio=16, block_id=1):
        """"""
        filters = inputs.shape[self.channel_axis]
        se_shape = (1, 1, filters) if self.channel_axis == -1 else (filters, 1, 1)
        
        se = GlobalAveragePooling2D(name="squeeze_glo_avg_%s" % block_id)(inputs)
        se = Dense(filters // ratio, activation="relu", 
                   kernel_initializer="he_normal",
                   kernel_regularizer=l2(self.reg),
                   use_bias=False, name="squeeze_squ_%s" % block_id)(se)
        se = Dense(filters, activation="relu", 
                   kernel_initializer="he_normal",
                   kernel_regularizer=l2(self.reg),
                   use_bias=False, 
                   name="squeeze_exci_%s" % block_id)(se)
        se = multiply([inputs, se], name="squeeze_scale_%s" % block_id)
        
        return se
    
    def _depthwise_conv_se_block(self, inputs, pointwise_conv_filters, alpha, 
                                 depth_multiplier=1, strides=(2, 2), block_id=1,
                                 kernel=(3,3), ratio=16):
        """
        DS-Conv + SE
        """
        x = self._depthwise_conv_block(inputs, pointwise_conv_filters, alpha, 
                                       block_id=block_id, strides=strides)
#         x = Activation("relu")(x)
        x = self._squeeze_excite_block(x, ratio=ratio, block_id=block_id)
        x = Activation("relu")(x)
        
        return x
    
    def _s2_block(self, inputs, pointwise_conv_filters, alpha, 
                  depth_multiplier=1, strides=(1, 1), block_id=1,
                  kernel=(3,3), pool_size=(1,1), padding_size=(1, 1)):
        x = AveragePooling2D(pool_size=pool_size, strides=(2, 2), 
                             data_format=IMAGE_DATA_FORMAT, padding="same")(inputs)
        x = Activation("relu")(x)
        x = self._depthwise_conv_block(x, pointwise_conv_filters, alpha, 
                                       block_id=block_id, kernel=kernel, 
                                       padding_size=padding_size)
        x = UpSampling2D(size=(2, 2), interpolation="bilinear", name="s2_block_%s" % block_id)(x)
        x = BatchNormalization(axis=self.channel_axis)(x)
        x = Activation("relu")(x)
        
        return x
    
    def _s2_module(self, inputs, pointwise_conv_filters, alpha,
                   depth_multiplier=1, strides=(1, 1), block_id=1,
                   kernel_conv=(3, 3), kernel_ds_1=(3, 3), 
                   kernel_ds_2=(3, 3), pad_ds_1=(1, 1), pad_ds_2=(1, 1),
                   pool_block_1=(1, 1), pool_block_2=(1, 1)):
        """
        The function to build S2 block
        """
        x = self._conv_block(inputs, pointwise_conv_filters, alpha, 
                             kernel=(1, 1), block_id=block_id, padding="same")
        x1 = self._s2_block(x, pointwise_conv_filters, alpha, depth_multiplier=depth_multiplier,
                            strides=strides, kernel=kernel_ds_1, block_id=str(block_id) + "_1",
                            padding_size=pad_ds_1, pool_size=pool_block_1)
    
        x2 = self._s2_block(x, pointwise_conv_filters, alpha, depth_multiplier=depth_multiplier,
                            strides=strides, kernel=kernel_ds_2, block_id=str(block_id) + "_2", 
                            padding_size=pad_ds_2, pool_size=pool_block_2)
        
        x = Concatenate(axis=self.channel_axis)([x1, x2])
        x = Add()([inputs, x])
#         x = BatchNormalization(axis=self.channel_axis)(x)
        x = PReLU()(x)
        
        return x
    
    def build_encoder(self):
        """
        Build encoder function
        """
        
        input_shape = (IMG_HEIGHT, IMG_WIDTH, IMG_CHANNEL)
        
        if IMAGE_DATA_FORMAT == "channels_first":
            input_shape = (IMG_CHANNEL, IMG_HEIGHT, IMG_WIDTH)
            
        inputs = Input(shape=input_shape)
        
        x = Lambda(lambda z: z[...,::-1], output_shape=input_shape, 
                   name="swap_color_channel")(inputs)
        
        if self.mean_substraction:
            x = Lambda(lambda z: (z - np.array(self.mean_substraction))*self.image_val,
                       output_shape=input_shape,
                       name="mean_substraction_inputs")(x)
#         x = inputs

        x1 = self._conv_block(x, 12, self.alpha, strides=(2, 2), block_id=1)
        x2 = self._depthwise_conv_se_block(x1, 16, self.alpha, block_id=2)
        x3 = self._depthwise_conv_se_block(x2, 48, self.alpha, block_id=3, strides=(1, 1))
        x4 = self._s2_module(x3, 24, self.alpha, block_id=4, kernel_ds_2=(5, 5), pad_ds_2=(2, 2))
        x5 = self._s2_module(x4, 24, self.alpha, block_id=5)
        
        x6 = Concatenate(axis=self.channel_axis, name="concat_2_5")([x2, x5])
        
        x7 = self._depthwise_conv_se_block(x6, 48, self.alpha, block_id=6)
        x8 = self._depthwise_conv_se_block(x7, 96, self.alpha, block_id=7, strides=(1, 1))
        x9 = self._s2_module(x8, 48, self.alpha, block_id=8, kernel_ds_2=(5, 5), pad_ds_2=(2, 2))
        x10 = self._s2_module(x9, 48, self.alpha, block_id=9)
        x11 = self._s2_module(x10, 48, self.alpha, block_id=10, 
                              kernel_ds_1=(5, 5), pad_ds_1=(2, 2),
                              kernel_ds_2=(3, 3), pool_block_2=(2, 2))
        x12 = self._s2_module(x11, 48, self.alpha, block_id=11,
                              kernel_ds_1=(5, 5), pad_ds_1=(2, 2),
                              kernel_ds_2=(3, 3), pool_block_2=(4, 4))
        x13 = self._s2_module(x12, 48, self.alpha, block_id=12)
        x14 = self._s2_module(x13, 48, self.alpha, block_id=13,
                              kernel_ds_1=(5, 5), pad_ds_1=(2, 2),
                              kernel_ds_2=(5, 5), pad_ds_2=(2, 2))
        x15 = self._s2_module(x14, 48, self.alpha, block_id=14,
                              kernel_ds_1=(3, 3), pool_block_1=(2, 2),
                              kernel_ds_2=(3, 3), pool_block_2=(4, 4))
        x16 = self._s2_module(x15, 48, self.alpha, block_id=15,
                              kernel_ds_1=(3, 3), pool_block_1=(1, 1),
                              kernel_ds_2=(5, 5), pad_ds_2=(2, 2), pool_block_2=(2, 2))
        
        x17 = Concatenate(axis=self.channel_axis, name="concat_16_7")([x16, x7])
        x17 = Activation("relu")(x17)
        
        x = self._pointwise_conv_block(x17, N_CLASSES, self.alpha, block_id=16)
#         x8_pws = self._pointwise_conv_block(x8, N_CLASSES, self.alpha, block_id=17)
#         x = Add(name="x8_xlast_adding")([x8_pws, x])
        x = Activation("relu")(x)
#         x = Activation("relu")(x)
        
#         x = Reshape((-1, self.n_classes))(x)
        
#         x = Activation("softmax")(x)
        
#         model = Model(inputs=inputs, outputs=x)
        
        return inputs, x, x8, x5, x1
    
    def build_decoder(self):
        inputs, x, x8, x5, x1 = self.build_encoder()
        
        x = UpSampling2D((2, 2), data_format=IMAGE_DATA_FORMAT, 
                         interpolation="bilinear")(x)
        x = BatchNormalization(axis=self.channel_axis)(x)
        x_ac = Activation("softmax")(x)
        
        x_blocking = K.max(x_ac, axis=-1, keepdims=True)
        
        x_blocking = Lambda(lambda x: 1 - x, name="information_blocking_decoder")(x_blocking)
        
        x5_pws = self._pointwise_conv_block(x5, self.n_classes, self.alpha, block_id=18)
        
        x_mul = Multiply()([x5_pws, x_blocking])
        x = Activation("relu")(x)
        x = Add()([x_mul, x])
        x = Activation("relu")(x)
        x = UpSampling2D((2, 2), interpolation="bilinear")(x)
        x = BatchNormalization(axis=self.channel_axis)(x)
        x = Activation("relu")(x)
        x = self._conv_block(x, self.n_classes, self.alpha, kernel=(1, 1), padding="same", block_id=19)
#         x1_pws = self._pointwise_conv_block(x1, self.n_classes, self.alpha, block_id=20, strides=(1, 1))
#         x = Add()([x1_pws, x])
#         x = Activation("relu")(x)
        x = UpSampling2D((2, 2), interpolation="bilinear")(x)
        x = BatchNormalization(axis=self.channel_axis)(x)
        x = Activation("relu")(x)
        x = Reshape((-1, self.n_classes))(x)
        x = Activation("softmax")(x)
        
        model = Model(inputs=inputs, outputs=x)
        
        return model

# %%
# K.max?

# %%
K.clear_session()
sinet = SiNet(IMG_HEIGHT, IMG_WIDTH, IMG_CHANNEL, N_CLASSES)

# %%
model = sinet.build_decoder()

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  swap_color_channel (Lambda)    (None, 224, 224, 3)  0           ['input_1[0][0]']
#
#  mean_substraction_inputs (Lamb  (None, 224, 224, 3)  0          ['swap_color_channel[0][0]']
#  da)
#
#  conv_1_pad (ZeroPadding2D)     (None, 226, 226, 3)  0           ['mean_substraction_inputs[0][0]'
#                                                                  ]
#
#  conv_1 (Conv2D)                (None, 112, 112, 12  324         ['conv_1_pad[0][0]']
#                                 )
#
#  conv_1_bn (BatchNormalization)  (None, 112, 112, 12  48         ['conv_1[0][0]']
#                                 )
#
#  conv_1_act (Activation)        (None, 112, 112, 12  0           ['conv_1_bn[0][0]']
#                                 )
#
#  conv_pad_2 (ZeroPadding2D)     (None, 114, 114, 12  0           ['conv_1_act[0][0]']
#                                 )
#
#  conv_dw_2 (DepthwiseConv2D)    (None, 56, 56, 12)   108         ['conv_pad_2[0][0]']
#
#  conv_dw_2_bn (BatchNormalizati  (None, 56, 56, 12)  48          ['conv_dw_2[0][0]']
#  on)
#
#  conv_dw_2_Prelu (PReLU)        (None, 56, 56, 12)   37632       ['conv_dw_2_bn[0][0]']
#
#  conv_pw_2 (Conv2D)             (None, 56, 56, 16)   192         ['conv_dw_2_Prelu[0][0]']
#
#  conv_pw_2_bn (BatchNormalizati  (None, 56, 56, 16)  64          ['conv_pw_2[0][0]']
#  on)
#
#  conv_pw_2_relu (Activation)    (None, 56, 56, 16)   0           ['conv_pw_2_bn[0][0]']
#
#  squeeze_glo_avg_2 (GlobalAvera  (None, 16)          0           ['conv_pw_2_relu[0][0]']
#  gePooling2D)
#
#  squeeze_squ_2 (Dense)          (None, 1)            16          ['squeeze_glo_avg_2[0][0]']
#
#  squeeze_exci_2 (Dense)         (None, 16)           16          ['squeeze_squ_2[0][0]']
#
#  squeeze_scale_2 (Multiply)     (None, 56, 56, 16)   0           ['conv_pw_2_relu[0][0]',
#                                                                   'squeeze_exci_2[0][0]']
#
#  activation (Activation)        (None, 56, 56, 16)   0           ['squeeze_scale_2[0][0]']
#
#  conv_pad_3 (ZeroPadding2D)     (None, 58, 58, 16)   0           ['activation[0][0]']
#
#  conv_dw_3 (DepthwiseConv2D)    (None, 56, 56, 16)   144         ['conv_pad_3[0][0]']
#
#  conv_dw_3_bn (BatchNormalizati  (None, 56, 56, 16)  64          ['conv_dw_3[0][0]']
#  on)
#
#  conv_dw_3_Prelu (PReLU)        (None, 56, 56, 16)   50176       ['conv_dw_3_bn[0][0]']
#
#  conv_pw_3 (Conv2D)             (None, 56, 56, 48)   768         ['conv_dw_3_Prelu[0][0]']
#
#  conv_pw_3_bn (BatchNormalizati  (None, 56, 56, 48)  192         ['conv_pw_3[0][0]']
#  on)
#
#  conv_pw_3_relu (Activation)    (None, 56, 56, 48)   0           ['conv_pw_3_bn[0][0]']
#
#  squeeze_glo_avg_3 (GlobalAvera  (None, 48)          0           ['conv_pw_3_relu[0][0]']
#  gePooling2D)
#
#  squeeze_squ_3 (Dense)          (None, 3)            144         ['squeeze_glo_avg_3[0][0]']
#
#  squeeze_exci_3 (Dense)         (None, 48)           144         ['squeeze_squ_3[0][0]']
#
#  squeeze_scale_3 (Multiply)     (None, 56, 56, 48)   0           ['conv_pw_3_relu[0][0]',
#                                                                   'squeeze_exci_3[0][0]']
#
#  activation_1 (Activation)      (None, 56, 56, 48)   0           ['squeeze_scale_3[0][0]']
#
#  conv_4 (Conv2D)                (None, 56, 56, 24)   1152        ['activation_1[0][0]']
#
#  conv_4_bn (BatchNormalization)  (None, 56, 56, 24)  96          ['conv_4[0][0]']
#
#  conv_4_act (Activation)        (None, 56, 56, 24)   0           ['conv_4_bn[0][0]']
#
#  average_pooling2d (AveragePool  (None, 28, 28, 24)  0           ['conv_4_act[0][0]']
#  ing2D)
#
#  average_pooling2d_1 (AveragePo  (None, 28, 28, 24)  0           ['conv_4_act[0][0]']
#  oling2D)
#
#  activation_2 (Activation)      (None, 28, 28, 24)   0           ['average_pooling2d[0][0]']
#
#  activation_4 (Activation)      (None, 28, 28, 24)   0           ['average_pooling2d_1[0][0]']
#
#  conv_pad_4_1 (ZeroPadding2D)   (None, 30, 30, 24)   0           ['activation_2[0][0]']
#
#  conv_pad_4_2 (ZeroPadding2D)   (None, 32, 32, 24)   0           ['activation_4[0][0]']
#
#  conv_dw_4_1 (DepthwiseConv2D)  (None, 28, 28, 24)   216         ['conv_pad_4_1[0][0]']
#
#  conv_dw_4_2 (DepthwiseConv2D)  (None, 28, 28, 24)   600         ['conv_pad_4_2[0][0]']
#
#  conv_dw_4_1_bn (BatchNormaliza  (None, 28, 28, 24)  96          ['conv_dw_4_1[0][0]']
#  tion)
#
#  conv_dw_4_2_bn (BatchNormaliza  (None, 28, 28, 24)  96          ['conv_dw_4_2[0][0]']
#  tion)
#
#  conv_dw_4_1_Prelu (PReLU)      (None, 28, 28, 24)   18816       ['conv_dw_4_1_bn[0][0]']
#
#  conv_dw_4_2_Prelu (PReLU)      (None, 28, 28, 24)   18816       ['conv_dw_4_2_bn[0][0]']
#
#  conv_pw_4_1 (Conv2D)           (None, 28, 28, 24)   576         ['conv_dw_4_1_Prelu[0][0]']
#
#  conv_pw_4_2 (Conv2D)           (None, 28, 28, 24)   576         ['conv_dw_4_2_Prelu[0][0]']
#
#  conv_pw_4_1_bn (BatchNormaliza  (None, 28, 28, 24)  96          ['conv_pw_4_1[0][0]']
#  tion)
#
#  conv_pw_4_2_bn (BatchNormaliza  (None, 28, 28, 24)  96          ['conv_pw_4_2[0][0]']
#  tion)
#
#  conv_pw_4_1_relu (Activation)  (None, 28, 28, 24)   0           ['conv_pw_4_1_bn[0][0]']
#
#  conv_pw_4_2_relu (Activation)  (None, 28, 28, 24)   0           ['conv_pw_4_2_bn[0][0]']
#
#  s2_block_4_1 (UpSampling2D)    (None, 56, 56, 24)   0           ['conv_pw_4_1_relu[0][0]']
#
#  s2_block_4_2 (UpSampling2D)    (None, 56, 56, 24)   0           ['conv_pw_4_2_relu[0][0]']
#
#  batch_normalization (BatchNorm  (None, 56, 56, 24)  96          ['s2_block_4_1[0][0]']
#  alization)
#
#  batch_normalization_1 (BatchNo  (None, 56, 56, 24)  96          ['s2_block_4_2[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 56, 56, 24)   0           ['batch_normalization[0][0]']
#
#  activation_5 (Activation)      (None, 56, 56, 24)   0           ['batch_normalization_1[0][0]']
#
#  concatenate (Concatenate)      (None, 56, 56, 48)   0           ['activation_3[0][0]',
#                                                                   'activation_5[0][0]']
#
#  add (Add)                      (None, 56, 56, 48)   0           ['activation_1[0][0]',
#                                                                   'concatenate[0][0]']
#
#  p_re_lu (PReLU)                (None, 56, 56, 48)   150528      ['add[0][0]']
#
#  conv_5 (Conv2D)                (None, 56, 56, 24)   1152        ['p_re_lu[0][0]']
#
#  conv_5_bn (BatchNormalization)  (None, 56, 56, 24)  96          ['conv_5[0][0]']
#
#  conv_5_act (Activation)        (None, 56, 56, 24)   0           ['conv_5_bn[0][0]']
#
#  average_pooling2d_2 (AveragePo  (None, 28, 28, 24)  0           ['conv_5_act[0][0]']
#  oling2D)
#
#  average_pooling2d_3 (AveragePo  (None, 28, 28, 24)  0           ['conv_5_act[0][0]']
#  oling2D)
#
#  activation_6 (Activation)      (None, 28, 28, 24)   0           ['average_pooling2d_2[0][0]']
#
#  activation_8 (Activation)      (None, 28, 28, 24)   0           ['average_pooling2d_3[0][0]']
#
#  conv_pad_5_1 (ZeroPadding2D)   (None, 30, 30, 24)   0           ['activation_6[0][0]']
#
#  conv_pad_5_2 (ZeroPadding2D)   (None, 30, 30, 24)   0           ['activation_8[0][0]']
#
#  conv_dw_5_1 (DepthwiseConv2D)  (None, 28, 28, 24)   216         ['conv_pad_5_1[0][0]']
#
#  conv_dw_5_2 (DepthwiseConv2D)  (None, 28, 28, 24)   216         ['conv_pad_5_2[0][0]']
#
#  conv_dw_5_1_bn (BatchNormaliza  (None, 28, 28, 24)  96          ['conv_dw_5_1[0][0]']
#  tion)
#
#  conv_dw_5_2_bn (BatchNormaliza  (None, 28, 28, 24)  96          ['conv_dw_5_2[0][0]']
#  tion)
#
#  conv_dw_5_1_Prelu (PReLU)      (None, 28, 28, 24)   18816       ['conv_dw_5_1_bn[0][0]']
#
#  conv_dw_5_2_Prelu (PReLU)      (None, 28, 28, 24)   18816       ['conv_dw_5_2_bn[0][0]']
#
#  conv_pw_5_1 (Conv2D)           (None, 28, 28, 24)   576         ['conv_dw_5_1_Prelu[0][0]']
#
#  conv_pw_5_2 (Conv2D)           (None, 28, 28, 24)   576         ['conv_dw_5_2_Prelu[0][0]']
#
#  conv_pw_5_1_bn (BatchNormaliza  (None, 28, 28, 24)  96          ['conv_pw_5_1[0][0]']
#  tion)
#
#  conv_pw_5_2_bn (BatchNormaliza  (None, 28, 28, 24)  96          ['conv_pw_5_2[0][0]']
#  tion)
#
#  conv_pw_5_1_relu (Activation)  (None, 28, 28, 24)   0           ['conv_pw_5_1_bn[0][0]']
#
#  conv_pw_5_2_relu (Activation)  (None, 28, 28, 24)   0           ['conv_pw_5_2_bn[0][0]']
#
#  s2_block_5_1 (UpSampling2D)    (None, 56, 56, 24)   0           ['conv_pw_5_1_relu[0][0]']
#
#  s2_block_5_2 (UpSampling2D)    (None, 56, 56, 24)   0           ['conv_pw_5_2_relu[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 56, 56, 24)  96          ['s2_block_5_1[0][0]']
#  rmalization)
#
#  batch_normalization_3 (BatchNo  (None, 56, 56, 24)  96          ['s2_block_5_2[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 56, 56, 24)   0           ['batch_normalization_2[0][0]']
#
#  activation_9 (Activation)      (None, 56, 56, 24)   0           ['batch_normalization_3[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 56, 56, 48)   0           ['activation_7[0][0]',
#                                                                   'activation_9[0][0]']
#
#  add_1 (Add)                    (None, 56, 56, 48)   0           ['p_re_lu[0][0]',
#                                                                   'concatenate_1[0][0]']
#
#  p_re_lu_1 (PReLU)              (None, 56, 56, 48)   150528      ['add_1[0][0]']
#
#  concat_2_5 (Concatenate)       (None, 56, 56, 64)   0           ['activation[0][0]',
#                                                                   'p_re_lu_1[0][0]']
#
#  conv_pad_6 (ZeroPadding2D)     (None, 58, 58, 64)   0           ['concat_2_5[0][0]']
#
#  conv_dw_6 (DepthwiseConv2D)    (None, 28, 28, 64)   576         ['conv_pad_6[0][0]']
#
#  conv_dw_6_bn (BatchNormalizati  (None, 28, 28, 64)  256         ['conv_dw_6[0][0]']
#  on)
#
#  conv_dw_6_Prelu (PReLU)        (None, 28, 28, 64)   50176       ['conv_dw_6_bn[0][0]']
#
#  conv_pw_6 (Conv2D)             (None, 28, 28, 48)   3072        ['conv_dw_6_Prelu[0][0]']
#
#  conv_pw_6_bn (BatchNormalizati  (None, 28, 28, 48)  192         ['conv_pw_6[0][0]']
#  on)
#
#  conv_pw_6_relu (Activation)    (None, 28, 28, 48)   0           ['conv_pw_6_bn[0][0]']
#
#  squeeze_glo_avg_6 (GlobalAvera  (None, 48)          0           ['conv_pw_6_relu[0][0]']
#  gePooling2D)
#
#  squeeze_squ_6 (Dense)          (None, 3)            144         ['squeeze_glo_avg_6[0][0]']
#
#  squeeze_exci_6 (Dense)         (None, 48)           144         ['squeeze_squ_6[0][0]']
#
#  squeeze_scale_6 (Multiply)     (None, 28, 28, 48)   0           ['conv_pw_6_relu[0][0]',
#                                                                   'squeeze_exci_6[0][0]']
#
#  activation_10 (Activation)     (None, 28, 28, 48)   0           ['squeeze_scale_6[0][0]']
#
#  conv_pad_7 (ZeroPadding2D)     (None, 30, 30, 48)   0           ['activation_10[0][0]']
#
#  conv_dw_7 (DepthwiseConv2D)    (None, 28, 28, 48)   432         ['conv_pad_7[0][0]']
#
#  conv_dw_7_bn (BatchNormalizati  (None, 28, 28, 48)  192         ['conv_dw_7[0][0]']
#  on)
#
#  conv_dw_7_Prelu (PReLU)        (None, 28, 28, 48)   37632       ['conv_dw_7_bn[0][0]']
#
#  conv_pw_7 (Conv2D)             (None, 28, 28, 96)   4608        ['conv_dw_7_Prelu[0][0]']
#
#  conv_pw_7_bn (BatchNormalizati  (None, 28, 28, 96)  384         ['conv_pw_7[0][0]']
#  on)
#
#  conv_pw_7_relu (Activation)    (None, 28, 28, 96)   0           ['conv_pw_7_bn[0][0]']
#
#  squeeze_glo_avg_7 (GlobalAvera  (None, 96)          0           ['conv_pw_7_relu[0][0]']
#  gePooling2D)
#
#  squeeze_squ_7 (Dense)          (None, 6)            576         ['squeeze_glo_avg_7[0][0]']
#
#  squeeze_exci_7 (Dense)         (None, 96)           576         ['squeeze_squ_7[0][0]']
#
#  squeeze_scale_7 (Multiply)     (None, 28, 28, 96)   0           ['conv_pw_7_relu[0][0]',
#                                                                   'squeeze_exci_7[0][0]']
#
#  activation_11 (Activation)     (None, 28, 28, 96)   0           ['squeeze_scale_7[0][0]']
#
#  conv_8 (Conv2D)                (None, 28, 28, 48)   4608        ['activation_11[0][0]']
#
#  conv_8_bn (BatchNormalization)  (None, 28, 28, 48)  192         ['conv_8[0][0]']
#
#  conv_8_act (Activation)        (None, 28, 28, 48)   0           ['conv_8_bn[0][0]']
#
#  average_pooling2d_4 (AveragePo  (None, 14, 14, 48)  0           ['conv_8_act[0][0]']
#  oling2D)
#
#  average_pooling2d_5 (AveragePo  (None, 14, 14, 48)  0           ['conv_8_act[0][0]']
#  oling2D)
#
#  activation_12 (Activation)     (None, 14, 14, 48)   0           ['average_pooling2d_4[0][0]']
#
#  activation_14 (Activation)     (None, 14, 14, 48)   0           ['average_pooling2d_5[0][0]']
#
#  conv_pad_8_1 (ZeroPadding2D)   (None, 16, 16, 48)   0           ['activation_12[0][0]']
#
#  conv_pad_8_2 (ZeroPadding2D)   (None, 18, 18, 48)   0           ['activation_14[0][0]']
#
#  conv_dw_8_1 (DepthwiseConv2D)  (None, 14, 14, 48)   432         ['conv_pad_8_1[0][0]']
#
#  conv_dw_8_2 (DepthwiseConv2D)  (None, 14, 14, 48)   1200        ['conv_pad_8_2[0][0]']
#
#  conv_dw_8_1_bn (BatchNormaliza  (None, 14, 14, 48)  192         ['conv_dw_8_1[0][0]']
#  tion)
#
#  conv_dw_8_2_bn (BatchNormaliza  (None, 14, 14, 48)  192         ['conv_dw_8_2[0][0]']
#  tion)
#
#  conv_dw_8_1_Prelu (PReLU)      (None, 14, 14, 48)   9408        ['conv_dw_8_1_bn[0][0]']
#
#  conv_dw_8_2_Prelu (PReLU)      (None, 14, 14, 48)   9408        ['conv_dw_8_2_bn[0][0]']
#
#  conv_pw_8_1 (Conv2D)           (None, 14, 14, 48)   2304        ['conv_dw_8_1_Prelu[0][0]']
#
#  conv_pw_8_2 (Conv2D)           (None, 14, 14, 48)   2304        ['conv_dw_8_2_Prelu[0][0]']
#
#  conv_pw_8_1_bn (BatchNormaliza  (None, 14, 14, 48)  192         ['conv_pw_8_1[0][0]']
#  tion)
#
#  conv_pw_8_2_bn (BatchNormaliza  (None, 14, 14, 48)  192         ['conv_pw_8_2[0][0]']
#  tion)
#
#  conv_pw_8_1_relu (Activation)  (None, 14, 14, 48)   0           ['conv_pw_8_1_bn[0][0]']
#
#  conv_pw_8_2_relu (Activation)  (None, 14, 14, 48)   0           ['conv_pw_8_2_bn[0][0]']
#
#  s2_block_8_1 (UpSampling2D)    (None, 28, 28, 48)   0           ['conv_pw_8_1_relu[0][0]']
#
#  s2_block_8_2 (UpSampling2D)    (None, 28, 28, 48)   0           ['conv_pw_8_2_relu[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 28, 28, 48)  192         ['s2_block_8_1[0][0]']
#  rmalization)
#
#  batch_normalization_5 (BatchNo  (None, 28, 28, 48)  192         ['s2_block_8_2[0][0]']
#  rmalization)
#
#  activation_13 (Activation)     (None, 28, 28, 48)   0           ['batch_normalization_4[0][0]']
#
#  activation_15 (Activation)     (None, 28, 28, 48)   0           ['batch_normalization_5[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 28, 28, 96)   0           ['activation_13[0][0]',
#                                                                   'activation_15[0][0]']
#
#  add_2 (Add)                    (None, 28, 28, 96)   0           ['activation_11[0][0]',
#                                                                   'concatenate_2[0][0]']
#
#  p_re_lu_2 (PReLU)              (None, 28, 28, 96)   75264       ['add_2[0][0]']
#
#  conv_9 (Conv2D)                (None, 28, 28, 48)   4608        ['p_re_lu_2[0][0]']
#
#  conv_9_bn (BatchNormalization)  (None, 28, 28, 48)  192         ['conv_9[0][0]']
#
#  conv_9_act (Activation)        (None, 28, 28, 48)   0           ['conv_9_bn[0][0]']
#
#  average_pooling2d_6 (AveragePo  (None, 14, 14, 48)  0           ['conv_9_act[0][0]']
#  oling2D)
#
#  average_pooling2d_7 (AveragePo  (None, 14, 14, 48)  0           ['conv_9_act[0][0]']
#  oling2D)
#
#  activation_16 (Activation)     (None, 14, 14, 48)   0           ['average_pooling2d_6[0][0]']
#
#  activation_18 (Activation)     (None, 14, 14, 48)   0           ['average_pooling2d_7[0][0]']
#
#  conv_pad_9_1 (ZeroPadding2D)   (None, 16, 16, 48)   0           ['activation_16[0][0]']
#
#  conv_pad_9_2 (ZeroPadding2D)   (None, 16, 16, 48)   0           ['activation_18[0][0]']
#
#  conv_dw_9_1 (DepthwiseConv2D)  (None, 14, 14, 48)   432         ['conv_pad_9_1[0][0]']
#
#  conv_dw_9_2 (DepthwiseConv2D)  (None, 14, 14, 48)   432         ['conv_pad_9_2[0][0]']
#
#  conv_dw_9_1_bn (BatchNormaliza  (None, 14, 14, 48)  192         ['conv_dw_9_1[0][0]']
#  tion)
#
#  conv_dw_9_2_bn (BatchNormaliza  (None, 14, 14, 48)  192         ['conv_dw_9_2[0][0]']
#  tion)
#
#  conv_dw_9_1_Prelu (PReLU)      (None, 14, 14, 48)   9408        ['conv_dw_9_1_bn[0][0]']
#
#  conv_dw_9_2_Prelu (PReLU)      (None, 14, 14, 48)   9408        ['conv_dw_9_2_bn[0][0]']
#
#  conv_pw_9_1 (Conv2D)           (None, 14, 14, 48)   2304        ['conv_dw_9_1_Prelu[0][0]']
#
#  conv_pw_9_2 (Conv2D)           (None, 14, 14, 48)   2304        ['conv_dw_9_2_Prelu[0][0]']
#
#  conv_pw_9_1_bn (BatchNormaliza  (None, 14, 14, 48)  192         ['conv_pw_9_1[0][0]']
#  tion)
#
#  conv_pw_9_2_bn (BatchNormaliza  (None, 14, 14, 48)  192         ['conv_pw_9_2[0][0]']
#  tion)
#
#  conv_pw_9_1_relu (Activation)  (None, 14, 14, 48)   0           ['conv_pw_9_1_bn[0][0]']
#
#  conv_pw_9_2_relu (Activation)  (None, 14, 14, 48)   0           ['conv_pw_9_2_bn[0][0]']
#
#  s2_block_9_1 (UpSampling2D)    (None, 28, 28, 48)   0           ['conv_pw_9_1_relu[0][0]']
#
#  s2_block_9_2 (UpSampling2D)    (None, 28, 28, 48)   0           ['conv_pw_9_2_relu[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 28, 28, 48)  192         ['s2_block_9_1[0][0]']
#  rmalization)
#
#  batch_normalization_7 (BatchNo  (None, 28, 28, 48)  192         ['s2_block_9_2[0][0]']
#  rmalization)
#
#  activation_17 (Activation)     (None, 28, 28, 48)   0           ['batch_normalization_6[0][0]']
#
#  activation_19 (Activation)     (None, 28, 28, 48)   0           ['batch_normalization_7[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 28, 28, 96)   0           ['activation_17[0][0]',
#                                                                   'activation_19[0][0]']
#
#  add_3 (Add)                    (None, 28, 28, 96)   0           ['p_re_lu_2[0][0]',
#                                                                   'concatenate_3[0][0]']
#
#  p_re_lu_3 (PReLU)              (None, 28, 28, 96)   75264       ['add_3[0][0]']
#
#  conv_10 (Conv2D)               (None, 28, 28, 48)   4608        ['p_re_lu_3[0][0]']
#
#  conv_10_bn (BatchNormalization  (None, 28, 28, 48)  192         ['conv_10[0][0]']
#  )
#
#  conv_10_act (Activation)       (None, 28, 28, 48)   0           ['conv_10_bn[0][0]']
#
#  average_pooling2d_8 (AveragePo  (None, 14, 14, 48)  0           ['conv_10_act[0][0]']
#  oling2D)
#
#  average_pooling2d_9 (AveragePo  (None, 14, 14, 48)  0           ['conv_10_act[0][0]']
#  oling2D)
#
#  activation_20 (Activation)     (None, 14, 14, 48)   0           ['average_pooling2d_8[0][0]']
#
#  activation_22 (Activation)     (None, 14, 14, 48)   0           ['average_pooling2d_9[0][0]']
#
#  conv_pad_10_1 (ZeroPadding2D)  (None, 18, 18, 48)   0           ['activation_20[0][0]']
#
#  conv_pad_10_2 (ZeroPadding2D)  (None, 16, 16, 48)   0           ['activation_22[0][0]']
#
#  conv_dw_10_1 (DepthwiseConv2D)  (None, 14, 14, 48)  1200        ['conv_pad_10_1[0][0]']
#
#  conv_dw_10_2 (DepthwiseConv2D)  (None, 14, 14, 48)  432         ['conv_pad_10_2[0][0]']
#
#  conv_dw_10_1_bn (BatchNormaliz  (None, 14, 14, 48)  192         ['conv_dw_10_1[0][0]']
#  ation)
#
#  conv_dw_10_2_bn (BatchNormaliz  (None, 14, 14, 48)  192         ['conv_dw_10_2[0][0]']
#  ation)
#
#  conv_dw_10_1_Prelu (PReLU)     (None, 14, 14, 48)   9408        ['conv_dw_10_1_bn[0][0]']
#
#  conv_dw_10_2_Prelu (PReLU)     (None, 14, 14, 48)   9408        ['conv_dw_10_2_bn[0][0]']
#
#  conv_pw_10_1 (Conv2D)          (None, 14, 14, 48)   2304        ['conv_dw_10_1_Prelu[0][0]']
#
#  conv_pw_10_2 (Conv2D)          (None, 14, 14, 48)   2304        ['conv_dw_10_2_Prelu[0][0]']
#
#  conv_pw_10_1_bn (BatchNormaliz  (None, 14, 14, 48)  192         ['conv_pw_10_1[0][0]']
#  ation)
#
#  conv_pw_10_2_bn (BatchNormaliz  (None, 14, 14, 48)  192         ['conv_pw_10_2[0][0]']
#  ation)
#
#  conv_pw_10_1_relu (Activation)  (None, 14, 14, 48)  0           ['conv_pw_10_1_bn[0][0]']
#
#  conv_pw_10_2_relu (Activation)  (None, 14, 14, 48)  0           ['conv_pw_10_2_bn[0][0]']
#
#  s2_block_10_1 (UpSampling2D)   (None, 28, 28, 48)   0           ['conv_pw_10_1_relu[0][0]']
#
#  s2_block_10_2 (UpSampling2D)   (None, 28, 28, 48)   0           ['conv_pw_10_2_relu[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 28, 28, 48)  192         ['s2_block_10_1[0][0]']
#  rmalization)
#
#  batch_normalization_9 (BatchNo  (None, 28, 28, 48)  192         ['s2_block_10_2[0][0]']
#  rmalization)
#
#  activation_21 (Activation)     (None, 28, 28, 48)   0           ['batch_normalization_8[0][0]']
#
#  activation_23 (Activation)     (None, 28, 28, 48)   0           ['batch_normalization_9[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 28, 28, 96)   0           ['activation_21[0][0]',
#                                                                   'activation_23[0][0]']
# ...
#  ormalization)
#
#  batch_normalization_17 (BatchN  (None, 28, 28, 48)  192         ['s2_block_14_2[0][0]']
#  ormalization)
#
#  activation_37 (Activation)     (None, 28, 28, 48)   0           ['batch_normalization_16[0][0]']
#
#  activation_39 (Activation)     (None, 28, 28, 48)   0           ['batch_normalization_17[0][0]']
#
#  concatenate_8 (Concatenate)    (None, 28, 28, 96)   0           ['activation_37[0][0]',
#                                                                   'activation_39[0][0]']
#
#  add_8 (Add)                    (None, 28, 28, 96)   0           ['p_re_lu_7[0][0]',
#                                                                   'concatenate_8[0][0]']
#
#  p_re_lu_8 (PReLU)              (None, 28, 28, 96)   75264       ['add_8[0][0]']
#
#  conv_15 (Conv2D)               (None, 28, 28, 48)   4608        ['p_re_lu_8[0][0]']
#
#  conv_15_bn (BatchNormalization  (None, 28, 28, 48)  192         ['conv_15[0][0]']
#  )
#
#  conv_15_act (Activation)       (None, 28, 28, 48)   0           ['conv_15_bn[0][0]']
#
#  average_pooling2d_18 (AverageP  (None, 14, 14, 48)  0           ['conv_15_act[0][0]']
#  ooling2D)
#
#  average_pooling2d_19 (AverageP  (None, 14, 14, 48)  0           ['conv_15_act[0][0]']
#  ooling2D)
#
#  activation_40 (Activation)     (None, 14, 14, 48)   0           ['average_pooling2d_18[0][0]']
#
#  activation_42 (Activation)     (None, 14, 14, 48)   0           ['average_pooling2d_19[0][0]']
#
#  conv_pad_15_1 (ZeroPadding2D)  (None, 16, 16, 48)   0           ['activation_40[0][0]']
#
#  conv_pad_15_2 (ZeroPadding2D)  (None, 18, 18, 48)   0           ['activation_42[0][0]']
#
#  conv_dw_15_1 (DepthwiseConv2D)  (None, 14, 14, 48)  432         ['conv_pad_15_1[0][0]']
#
#  conv_dw_15_2 (DepthwiseConv2D)  (None, 14, 14, 48)  1200        ['conv_pad_15_2[0][0]']
#
#  conv_dw_15_1_bn (BatchNormaliz  (None, 14, 14, 48)  192         ['conv_dw_15_1[0][0]']
#  ation)
#
#  conv_dw_15_2_bn (BatchNormaliz  (None, 14, 14, 48)  192         ['conv_dw_15_2[0][0]']
#  ation)
#
#  conv_dw_15_1_Prelu (PReLU)     (None, 14, 14, 48)   9408        ['conv_dw_15_1_bn[0][0]']
#
#  conv_dw_15_2_Prelu (PReLU)     (None, 14, 14, 48)   9408        ['conv_dw_15_2_bn[0][0]']
#
#  conv_pw_15_1 (Conv2D)          (None, 14, 14, 48)   2304        ['conv_dw_15_1_Prelu[0][0]']
#
#  conv_pw_15_2 (Conv2D)          (None, 14, 14, 48)   2304        ['conv_dw_15_2_Prelu[0][0]']
#
#  conv_pw_15_1_bn (BatchNormaliz  (None, 14, 14, 48)  192         ['conv_pw_15_1[0][0]']
#  ation)
#
#  conv_pw_15_2_bn (BatchNormaliz  (None, 14, 14, 48)  192         ['conv_pw_15_2[0][0]']
#  ation)
#
#  conv_pw_15_1_relu (Activation)  (None, 14, 14, 48)  0           ['conv_pw_15_1_bn[0][0]']
#
#  conv_pw_15_2_relu (Activation)  (None, 14, 14, 48)  0           ['conv_pw_15_2_bn[0][0]']
#
#  s2_block_15_1 (UpSampling2D)   (None, 28, 28, 48)   0           ['conv_pw_15_1_relu[0][0]']
#
#  s2_block_15_2 (UpSampling2D)   (None, 28, 28, 48)   0           ['conv_pw_15_2_relu[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 28, 28, 48)  192         ['s2_block_15_1[0][0]']
#  ormalization)
#
#  batch_normalization_19 (BatchN  (None, 28, 28, 48)  192         ['s2_block_15_2[0][0]']
#  ormalization)
#
#  activation_41 (Activation)     (None, 28, 28, 48)   0           ['batch_normalization_18[0][0]']
#
#  activation_43 (Activation)     (None, 28, 28, 48)   0           ['batch_normalization_19[0][0]']
#
#  concatenate_9 (Concatenate)    (None, 28, 28, 96)   0           ['activation_41[0][0]',
#                                                                   'activation_43[0][0]']
#
#  add_9 (Add)                    (None, 28, 28, 96)   0           ['p_re_lu_8[0][0]',
#                                                                   'concatenate_9[0][0]']
#
#  p_re_lu_9 (PReLU)              (None, 28, 28, 96)   75264       ['add_9[0][0]']
#
#  concat_16_7 (Concatenate)      (None, 28, 28, 144)  0           ['p_re_lu_9[0][0]',
#                                                                   'activation_10[0][0]']
#
#  activation_44 (Activation)     (None, 28, 28, 144)  0           ['concat_16_7[0][0]']
#
#  conv_pw_16 (Conv2D)            (None, 28, 28, 2)    288         ['activation_44[0][0]']
#
#  conv_pw_16_bn (BatchNormalizat  (None, 28, 28, 2)   8           ['conv_pw_16[0][0]']
#  ion)
#
#  conv_pw_16_relu (Activation)   (None, 28, 28, 2)    0           ['conv_pw_16_bn[0][0]']
#
#  activation_45 (Activation)     (None, 28, 28, 2)    0           ['conv_pw_16_relu[0][0]']
#
#  up_sampling2d (UpSampling2D)   (None, 56, 56, 2)    0           ['activation_45[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 56, 56, 2)   8           ['up_sampling2d[0][0]']
#  ormalization)
#
#  conv_pw_18 (Conv2D)            (None, 56, 56, 2)    96          ['p_re_lu_1[0][0]']
#
#  activation_46 (Activation)     (None, 56, 56, 2)    0           ['batch_normalization_20[0][0]']
#
#  conv_pw_18_bn (BatchNormalizat  (None, 56, 56, 2)   8           ['conv_pw_18[0][0]']
#  ion)
#
#  tf.math.reduce_max (TFOpLambda  (None, 56, 56, 1)   0           ['activation_46[0][0]']
#  )
#
#  conv_pw_18_relu (Activation)   (None, 56, 56, 2)    0           ['conv_pw_18_bn[0][0]']
#
#  information_blocking_decoder (  (None, 56, 56, 1)   0           ['tf.math.reduce_max[0][0]']
#  Lambda)
#
#  multiply (Multiply)            (None, 56, 56, 2)    0           ['conv_pw_18_relu[0][0]',
#                                                                   'information_blocking_decoder[0]
#                                                                  [0]']
#
#  activation_47 (Activation)     (None, 56, 56, 2)    0           ['batch_normalization_20[0][0]']
#
#  add_10 (Add)                   (None, 56, 56, 2)    0           ['multiply[0][0]',
#                                                                   'activation_47[0][0]']
#
#  activation_48 (Activation)     (None, 56, 56, 2)    0           ['add_10[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (None, 112, 112, 2)  0          ['activation_48[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 112, 112, 2)  8          ['up_sampling2d_1[0][0]']
#  ormalization)
#
#  activation_49 (Activation)     (None, 112, 112, 2)  0           ['batch_normalization_21[0][0]']
#
#  conv_19 (Conv2D)               (None, 112, 112, 2)  4           ['activation_49[0][0]']
#
#  conv_19_bn (BatchNormalization  (None, 112, 112, 2)  8          ['conv_19[0][0]']
#  )
#
#  conv_19_act (Activation)       (None, 112, 112, 2)  0           ['conv_19_bn[0][0]']
#
#  up_sampling2d_2 (UpSampling2D)  (None, 224, 224, 2)  0          ['conv_19_act[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 224, 224, 2)  8          ['up_sampling2d_2[0][0]']
#  ormalization)
#
#  activation_50 (Activation)     (None, 224, 224, 2)  0           ['batch_normalization_22[0][0]']
#
#  reshape (Reshape)              (None, 50176, 2)     0           ['activation_50[0][0]']
#
#  activation_51 (Activation)     (None, 50176, 2)     0           ['reshape[0][0]']
#
# ==================================================================================================
# Total params: 1,421,636
# Trainable params: 1,414,844
# Non-trainable params: 6,792
# __________________________________________________________________________________________________

# %%
plot_model(model)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model/model_to_dot to work.

# %% [markdown]
# ## Dataset Generation

# %%
# !ls
# Out:
# EG1800_train.txt  Sinet.ipynb		    train.txt
# EG1800_val.txt	  sinet-segmentation.ipynb  val.txt

# %%
# with open("train.txt") as f:
#     data = f.read()

# %%
files = pd.read_csv("train.txt", header=None)[0]

# %%
files.values
# Out:
# array([   1,    3,    4, ..., 2630, 2631, 2632])

# %%
class DataAugmentation:
    def __init__(self):
        self.IMAGE_AUGMENTATION_SEQUENCE = None
        self.IMAGE_AUGMENTATION_NUM_TRIES = 10
        self.loaded_augmentation_name = ""
    
        self.augmentation_functions = {
            "aug_all": self._load_augmentation_aug_all,
            "aug_geometric": self._load_augmentation_aug_geometric,
            "aug_non_geometric": self._load_augmentation_aug_non_geometric,
        }
    
    def _load_augmentation_aug_geometric(self):
        return iaa.Sequential([
            iaa.Sometimes(0.5, iaa.Fliplr()),
            iaa.Sometimes(0.5, iaa.Rotate((-45, 45))),
            iaa.Sometimes(0.5, iaa.Affine(
                scale={"x": (0.5, 1.5), "y": (0.5, 1.5)},
                order=[0, 1],
                mode='constant',
                cval=(0, 255),
            )),
            iaa.Sometimes(0.5, iaa.Affine(
                translate_percent={"x": (-0.25, 0.25), "y": (-0.25, 0.25)},
                order=[0, 1],
                mode='constant',
                cval=(0, 255),
            )),
        ])
    
    def _load_augmentation_aug_non_geometric(self):
        return iaa.Sequential([
            iaa.Sometimes(0.5, iaa.AdditiveGaussianNoise(loc=0, scale=(0.0, 0.05*255), per_channel=0.5)),
            iaa.Sometimes(0.5, iaa.OneOf([
                iaa.GaussianBlur(sigma=(0.0, 3.0)),
                iaa.GaussianBlur(sigma=(0.0, 5.0))
            ])),
            iaa.Sometimes(0.5, iaa.MultiplyAndAddToBrightness(mul=(0.4, 1.7))),
            iaa.Sometimes(0.5, iaa.GammaContrast((0.4, 1.7))),
            iaa.Sometimes(0.5, iaa.Multiply((0.4, 1.7), per_channel=0.5)),
            iaa.Sometimes(0.5, iaa.MultiplyHue((0.4, 1.7))),
            iaa.Sometimes(0.5, iaa.MultiplyHueAndSaturation((0.4, 1.7), per_channel=True)),
            iaa.Sometimes(0.5, iaa.LinearContrast((0.4, 1.7), per_channel=0.5))
        ])
    
    def _load_augmentation_aug_all(self):
        return iaa.OneOf([
            iaa.Sometimes(0.5, self._load_augmentation_aug_geometric()),
            iaa.Sometimes(0.5, self._load_augmentation_aug_non_geometric())
        ])
    
    def _load_aug_by_name(self, aug_name="aug_all"):
        if not len(self.loaded_augmentation_name):
            self.loaded_augmentation_name = aug_name
            self.IMAGE_AUGMENTATION_SEQUENCE = self.augmentation_functions[aug_name]()
            
        return self.IMAGE_AUGMENTATION_SEQUENCE

# %%
DATA_DIR = "/"
TRAIN_ANNO_FILE1 = os.path.join("train.txt")
TRAIN_ANNO_FILE2 = os.path.join("EG1800_train.txt")
VAL_ANNO_FILE1 = os.path.join("val.txt")
VAL_ANNO_FILE2 = os.path.join("EG1800_val.txt")

# %%
class DataGenerator:
    def __init__(self, 
                 data_dir, 
                 anno_paths, 
                 augment_func,
                 img_height=IMG_HEIGHT,
                 img_width=IMG_WIDTH,
                 img_channel=IMG_CHANNEL,
                 batch_size=36,
                 n_classes=N_CLASSES,
                 augmentation=True,
                 task="train"):
        
        self.data_dir = data_dir
        self.anno_paths = anno_paths
        self.augment_func = augment_func
        self.batch_size = batch_size
        self.task = task
        self.current_index = 0
#         self.current_test = 0
        self.img_height = img_height
        self.img_width = img_width
        self.img_channel = img_channel
        self.n_classes = n_classes
        self.augmentation = augmentation
        self.image_paths, self.label_paths = self.load_image_paths("input", "target")

        print(self.anno_paths)
        
    def load_image_paths(self, input_dir, target_dir):
        image_paths = []
        label_paths = []
        
        for anno_path in self.anno_paths:
            anno_dir = os.path.dirname(anno_path)
            df_file_names = pd.read_csv(anno_path, header=None)
            file_names = df_file_names[0].values
    
            for fn in file_names:
                if "DS_Store" in fn: continue
                img_train_dir = os.path.join(anno_dir, input_dir)
                img_label_dir = os.path.join(anno_dir, target_dir)
                img_train_path = os.path.join(img_train_dir, fn)
                img_label_path = os.path.join(img_label_dir, fn)
        
                image_paths.append(img_train_path)
                label_paths.append(img_label_path)
                
        image_paths = np.array(image_paths)
        label_paths = np.array(label_paths)

        return image_paths, label_paths
    
    def get_n_examples(self):
        return len(self.image_paths)
        
    def load_image(self, img_path):
        image = cv2.imread(img_path, 1)
#         image = image[..., ::-1]
#         print(len(np.unique(image[..., 0])))
        return image

    def load_images(self, image_paths):
        images = []
        preprocessors = [self.resize_img, self.mean_substraction]
        
        for img_path in image_paths:
            image = self.load_image(img_path)
            image = self.preprocessing(image, preprocessors=preprocessors)
            images.append(image)
        
        images = np.array(images)
        return images
    
    def load_labels(self, label_paths):
        labels = []
        
        for lbl_path in label_paths:
            label = self.load_image(lbl_path)
            label = self.resize_img(label, interpolation=cv2.INTER_NEAREST)
            label = label /255
            label[label < 0.5] = 0
            label[label >= 0.5] = 1
            label = self.parse_label(label)
            labels.append(label)
        
        labels = np.array(labels)
        
        return labels
    
    def parse_label(self, seg_image):
        label = seg_image
        label = label[:, :, 0]
        seg = np.zeros((self.img_height, self.img_width, self.n_classes))
        
        for i in range(self.n_classes):
            seg[:, :, i] = (label == i).astype(int)
        
        seg = np.reshape(seg, (-1, self.n_classes))
        return seg
    
    def load_batch_pair_in_pair(self, img_paths, label_paths):
        images = []
        segs = []
        preprocessors = [self.resize_img, self.mean_substraction]
        
        for i in range(len(img_paths)):
            image = self.load_image(img_paths[i])
#             image = self.preprocessing(image, preprocessors)
            
            seg = self.load_image(label_paths[i])
#             seg = self.preprocessing(seg, [self.resize_img])
#             print(seg.dtype)
#             seg = seg.astype(np.uint8)
#             seg = self.parse_label(seg)
#             seg = np.argmax(seg, axis=-1).astype(np.int32)
            segmap = SegmentationMapsOnImage(seg[:, :, 0], shape=image.shape, nb_classes=np.max(seg[:, :, 0]) + 1)
            
            if self.augmentation:
                image, segmap = self.augment_func(image=image, segmentation_maps=segmap)
            
            seg[:, :, 0] = segmap.get_arr_int()
            image = self.preprocessing(image, preprocessors)
            
#             seg = self.preprocessing(seg, [self.resize_img])
            seg = self.resize_img(seg, interpolation=cv2.INTER_NEAREST)
            seg = seg /255
            seg[seg > 0.5] = 1
            seg[seg <= 0.5] = 0
            seg = self.parse_label(seg)
            
            images.append(image)
            segs.append(seg)
        
        return np.array(images), np.array(segs)
    
    def show_sample_image(self):
        idx = np.random.choice(len(self.image_paths), 1)[0]
        img_path = self.image_paths[idx]
        seg_path = self.label_paths[idx]
        
        img = self.load_image(img_path)
        seg = self.load_image(seg_path)
#         segmap = SegmentationMapsOnImage(seg[..., 0], shape=img.shape)
        segmap = SegmentationMapsOnImage(seg, shape=img.shape)
        
        img_aug, seg_aug = self.augment_func(image=img, segmentation_maps=segmap)
        
        ia.imshow(np.hstack([
            img[..., ::-1],
            seg
        ]))
        
#         seg[..., 0] = seg_aug.get_arr_int()
        seg = seg_aug.get_arr_int()
#         print(np.nonzero(seg[..., 0]))

#         non_index = np.nonzero(seg[..., 0])
#         for i in range(len(non_index[0])):
#             print(seg[..., 0][non_index[0][i], non_index[1][i]])

        ia.imshow(np.hstack([
            img_aug[..., ::-1],
            seg
        ]))
        
        seg = seg /255
        seg[seg < 0.5] = 0
        seg[seg >= 0.5] = 1
        
        ia.imshow(np.hstack([
            img_aug[..., ::-1],
            seg
        ]))
    
    def resize_img(self, image, interpolation=cv2.INTER_AREA):
#         h, w = image.shape[:2]
#         print(h, w)
#         p_h, p_w = 0, 0
        
#         if h>w:
#             image = imutils.resize(image, width=self.img_width)
#             p_h = int((image.shape[0] - self.img_height) / 2)
#         else:
#             image = imutils.resize(image, height=self.img_height)
#             p_w = int((image.shape[1] - self.img_width) / 2)
        
#         image = image[p_w:image.shape[1]-p_w, p_h: image.shape[0]-p_h]
        image = cv2.resize(image, (self.img_height, self.img_width), interpolation=interpolation)
        return image
    
    def mean_substraction(self, image, mean=[103.94, 116.78, 123.68], image_val=0.017):
        image = image.astype("float32")
        image[:, :, 0] -= mean[0]
        image[:, :, 1] -= mean[1]
        image[:, :, 2] -= mean[2]
        image *= image_val
        image = image[..., ::-1]
        
        return image
    
    def preprocessing(self, image, preprocessors):
        for p in preprocessors:
            image = p(image)
        
        return image
    
    def load_batch(self):
        if self.current_index + self.batch_size >= len(self.image_paths):
            self.current_index = 0
            self.image_paths, self.label_paths = shuffle(self.image_paths, self.label_paths, random_state=42)
            
        img_batch_paths = self.image_paths[self.current_index:self.current_index+self.batch_size]
        seg_batch_paths = self.label_paths[self.current_index:self.current_index+self.batch_size]
        self.current_index += self.batch_size
        inputs, segs = self.load_batch_pair_in_pair(img_batch_paths, seg_batch_paths)
        
        return inputs, segs
    
    def generate(self):
        while True:
            images, labels = self.load_batch()
            
            yield (images, labels)

# %%
data_aug = DataAugmentation()

# %%
aug = data_aug._load_aug_by_name()

# %%
train_datagen = DataGenerator(DATA_DIR, str[TRAIN_ANNO_FILE1, TRAIN_ANNO_FILE2], aug, batch_size=24)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [51], in <cell line: 1>()
# ----> 1 train_datagen = DataGenerator(DATA_DIR, [TRAIN_ANNO_FILE1, TRAIN_ANNO_FILE2], aug, batch_size=24)
#
# Input In [40], in DataGenerator.__init__(self, data_dir, anno_paths, augment_func, img_height, img_width, img_channel, batch_size, n_classes, augmentation, task)
#      24 self.n_classes = n_classes
#      25 self.augmentation = augmentation
# ---> 26 self.image_paths, self.label_paths = self.load_image_paths("input", "target")
#
# Input In [40], in DataGenerator.load_image_paths(self, input_dir, target_dir)
#      35 file_names = df_file_names[0].values
#      37 for fn in file_names:
# ---> 38     if "DS_Store" in fn: continue
#      39     img_train_dir = os.path.join(anno_dir, input_dir)
#      40     img_label_dir = os.path.join(anno_dir, target_dir)
#
# TypeError: argument of type 'numpy.int64' is not iterable

# %%
train_datagen.get_n_examples()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [49], in <cell line: 1>()
# ----> 1 train_datagen.get_n_examples()
#
# NameError: name 'train_datagen' is not defined

# %%
train_datagen.label_paths
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [48], in <cell line: 1>()
# ----> 1 train_datagen.label_paths
#
# NameError: name 'train_datagen' is not defined

# %%
train_datagen.show_sample_image()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
val_datagen = DataGenerator(DATA_DIR, [VAL_ANNO_FILE1, VAL_ANNO_FILE2], aug, batch_size=24)

# %%
val_datagen.get_n_examples()
# Out:
# 600

# %%
# val_datagen.label_paths

# %%
# show_sample_image(val_datagen.label_paths)

# %%
# imutils.resize?

# %% [markdown]
# ## Training Model

# %%
from keras.optimizers import Adam
import keras.backend as K
import tensorflow as tf
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
# frotensorflow.no_op.n

# %%
class SINetLoss:
    def __init__(self, lamda=0.9):
        self.lamda = lamda
        
    def gt_dilation(self, y_true):
        y_true = tf.reshape(y_true, (-1, IMG_HEIGHT, IMG_WIDTH, N_CLASSES))
        dilation = tf.nn.max_pool2d(y_true, ksize=(15, 15), strides=1, name='dilation2D', padding="SAME")
        dilation = tf.reshape(dilation, (-1, IMG_HEIGHT*IMG_WIDTH, N_CLASSES))
        
        return dilation
    
    def gt_erosion(self, y_true):
        y_true = tf.reshape(y_true, (-1, IMG_HEIGHT, IMG_WIDTH, N_CLASSES))
        erosion = -tf.nn.max_pool2d(-y_true, ksize=(15, 15), strides=1, name='erosion2D', padding="SAME")
        erosion = tf.reshape(erosion, (-1, IMG_HEIGHT*IMG_WIDTH, N_CLASSES))
        
        return erosion
        
    def log_loss(self, y_true, y_pred):
        loss = -tf.reduce_sum(y_true * tf.math.log(y_pred), axis=-1)
        return loss
        
    def boundary_loss(self, y_true, y_pred):
        dilation = self.gt_dilation(y_true)
        erosion = self.gt_erosion(y_true)

        boundary = tf.math.subtract(dilation, erosion)
#         boundary = tf.reshape(boundary, (-1, IMG_HEIGHT*IMG_WIDTH, N_CLASSES))
#         assign_indices = tf.count_nonzero(boundary, axis=-1)
#         assign_indices = tf.where(boundary)
#         print(tf.shape(boundary).eval(session=tf.compat.v1.Session()))
#         mask = tf.math.greater(tf.to_float(boundary), tf.constant(0.0))
#         zeros_mask = tf.zeros_like(boundary)
        
#         b_true = tf.where(mask, y_true, zeros_mask)
#         b_pred = tf.where(mask, y_pred, zeros_mask)
        loss = -tf.reduce_sum(boundary * tf.math.log(y_pred), axis=-1)
        
        return loss
    
    def compute_loss(self, y_true, y_pred):
        batch_size = tf.shape(y_pred)[0]
        self.lamda = self.lamda
        log_loss_ = tf.cast(self.log_loss(y_true, y_pred), tf.float32)
        boundary_loss_ = tf.cast(self.boundary_loss(y_true, y_pred), tf.float32)
        total_loss = log_loss_ + self.lamda * boundary_loss_
#         total_loss = tf.cast(total_loss, tf.float32)
        total_loss *= tf.cast(batch_size, tf.float32)
        
        return total_loss

# %%
# tf.nn.dilation2d?

# %%
sinet_loss = SINetLoss().compute_loss

# %%
init_lr = 7.5e-3

opt = Adam(lr=init_lr, decay=2e-4, beta_1=0.9, beta_2=0.999, epsilon=1e-07,)

# %%
model.compile(optimizer=opt, loss=sinet_loss, metrics=["accuracy"])

# %%
trained_weight = "trained_weight"

if not os.path.exists(trained_weight):
    os.mkdir(trained_weight)

# %%
import keras.backend as K
import keras.callbacks as cbks

# %%
class CustomMetrics(cbks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        for k in logs:
            if k.endswith('boundary_loss'):
                print(logs[k])

# %%
# checkpoints = ModelCheckpoint(filepath=os.path.join(trained_weight, "best_weights.h5"), 
#                               monitor="val_loss", 
#                               save_weights_only=True,
#                               save_best_only=True,
#                               verbose=1)

# %%
# !ls trained_weight/
# Out:
# best_weight.hdf5       best_weights_2.h5      best_weights_4.h5
# best_weights_1_all.h5  best_weights_3.h5      best_weights_all.h5
# best_weights_2_all.h5  best_weights_4_all.h5  best_weights.h5

# %%
checkpoints = ModelCheckpoint(filepath=os.path.join(trained_weight, "best_weights_4_all.h5"), 
                              monitor="val_loss", 
                              save_weights_only=True,
                              save_best_only=True,
                              verbose=1)

# %%
for idx, layer in enumerate(model.layers):
    print(idx, layer.name, layer.trainable)
    
    layer.trainable = True
#     if idx > 361:
#         layer.trainable = False
# Out:
# 0 input_1 True
# 1 swap_color_channel True
# 2 mean_substraction_inputs True
# 3 conv_1_pad True
# 4 conv_1 True
# 5 conv_1_bn True
# 6 conv_1_act True
# 7 conv_pad_2 True
# 8 conv_dw_2 True
# 9 conv_dw_2_bn True
# 10 conv_dw_2_Prelu True
# 11 conv_pw_2 True
# 12 conv_pw_2_bn True
# 13 conv_pw_2_relu True
# 14 squeeze_glo_avg_2 True
# 15 squeeze_squ_2 True
# 16 squeeze_exci_2 True
# 17 squeeze_scale_2 True
# 18 activation True
# 19 conv_pad_3 True
# 20 conv_dw_3 True
# 21 conv_dw_3_bn True
# 22 conv_dw_3_Prelu True
# 23 conv_pw_3 True
# 24 conv_pw_3_bn True
# 25 conv_pw_3_relu True
# 26 squeeze_glo_avg_3 True
# 27 squeeze_squ_3 True
# 28 squeeze_exci_3 True
# 29 squeeze_scale_3 True
# 30 activation_1 True
# 31 conv_4 True
# 32 conv_4_bn True
# 33 conv_4_act True
# 34 average_pooling2d True
# 35 average_pooling2d_1 True
# 36 activation_2 True
# 37 activation_4 True
# 38 conv_pad_4_1 True
# 39 conv_pad_4_2 True
# 40 conv_dw_4_1 True
# 41 conv_dw_4_2 True
# 42 conv_dw_4_1_bn True
# 43 conv_dw_4_2_bn True
# 44 conv_dw_4_1_Prelu True
# 45 conv_dw_4_2_Prelu True
# 46 conv_pw_4_1 True
# 47 conv_pw_4_2 True
# 48 conv_pw_4_1_bn True
# 49 conv_pw_4_2_bn True
# 50 conv_pw_4_1_relu True
# 51 conv_pw_4_2_relu True
# 52 s2_block_4_1 True
# 53 s2_block_4_2 True
# 54 batch_normalization True
# 55 batch_normalization_1 True
# 56 activation_3 True
# 57 activation_5 True
# 58 concatenate True
# 59 add True
# 60 p_re_lu True
# 61 conv_5 True
# 62 conv_5_bn True
# 63 conv_5_act True
# 64 average_pooling2d_2 True
# 65 average_pooling2d_3 True
# 66 activation_6 True
# 67 activation_8 True
# 68 conv_pad_5_1 True
# 69 conv_pad_5_2 True
# 70 conv_dw_5_1 True
# 71 conv_dw_5_2 True
# 72 conv_dw_5_1_bn True
# 73 conv_dw_5_2_bn True
# 74 conv_dw_5_1_Prelu True
# 75 conv_dw_5_2_Prelu True
# 76 conv_pw_5_1 True
# 77 conv_pw_5_2 True
# 78 conv_pw_5_1_bn True
# 79 conv_pw_5_2_bn True
# 80 conv_pw_5_1_relu True
# 81 conv_pw_5_2_relu True
# 82 s2_block_5_1 True
# 83 s2_block_5_2 True
# 84 batch_normalization_2 True
# 85 batch_normalization_3 True
# 86 activation_7 True
# 87 activation_9 True
# 88 concatenate_1 True
# 89 add_1 True
# 90 p_re_lu_1 True
# 91 concat_2_5 True
# 92 conv_pad_6 True
# 93 conv_dw_6 True
# 94 conv_dw_6_bn True
# 95 conv_dw_6_Prelu True
# 96 conv_pw_6 True
# 97 conv_pw_6_bn True
# 98 conv_pw_6_relu True
# 99 squeeze_glo_avg_6 True
# 100 squeeze_squ_6 True
# 101 squeeze_exci_6 True
# 102 squeeze_scale_6 True
# 103 activation_10 True
# 104 conv_pad_7 True
# 105 conv_dw_7 True
# 106 conv_dw_7_bn True
# 107 conv_dw_7_Prelu True
# 108 conv_pw_7 True
# 109 conv_pw_7_bn True
# 110 conv_pw_7_relu True
# 111 squeeze_glo_avg_7 True
# 112 squeeze_squ_7 True
# 113 squeeze_exci_7 True
# 114 squeeze_scale_7 True
# 115 activation_11 True
# 116 conv_8 True
# 117 conv_8_bn True
# 118 conv_8_act True
# 119 average_pooling2d_4 True
# 120 average_pooling2d_5 True
# 121 activation_12 True
# 122 activation_14 True
# 123 conv_pad_8_1 True
# 124 conv_pad_8_2 True
# 125 conv_dw_8_1 True
# 126 conv_dw_8_2 True
# 127 conv_dw_8_1_bn True
# 128 conv_dw_8_2_bn True
# 129 conv_dw_8_1_Prelu True
# 130 conv_dw_8_2_Prelu True
# 131 conv_pw_8_1 True
# 132 conv_pw_8_2 True
# 133 conv_pw_8_1_bn True
# 134 conv_pw_8_2_bn True
# 135 conv_pw_8_1_relu True
# 136 conv_pw_8_2_relu True
# 137 s2_block_8_1 True
# 138 s2_block_8_2 True
# 139 batch_normalization_4 True
# 140 batch_normalization_5 True
# 141 activation_13 True
# 142 activation_15 True
# 143 concatenate_2 True
# 144 add_2 True
# 145 p_re_lu_2 True
# 146 conv_9 True
# 147 conv_9_bn True
# 148 conv_9_act True
# 149 average_pooling2d_6 True
# 150 average_pooling2d_7 True
# 151 activation_16 True
# 152 activation_18 True
# 153 conv_pad_9_1 True
# 154 conv_pad_9_2 True
# 155 conv_dw_9_1 True
# 156 conv_dw_9_2 True
# 157 conv_dw_9_1_bn True
# 158 conv_dw_9_2_bn True
# 159 conv_dw_9_1_Prelu True
# 160 conv_dw_9_2_Prelu True
# 161 conv_pw_9_1 True
# 162 conv_pw_9_2 True
# 163 conv_pw_9_1_bn True
# 164 conv_pw_9_2_bn True
# 165 conv_pw_9_1_relu True
# 166 conv_pw_9_2_relu True
# 167 s2_block_9_1 True
# 168 s2_block_9_2 True
# 169 batch_normalization_6 True
# 170 batch_normalization_7 True
# 171 activation_17 True
# 172 activation_19 True
# 173 concatenate_3 True
# 174 add_3 True
# 175 p_re_lu_3 True
# 176 conv_10 True
# 177 conv_10_bn True
# 178 conv_10_act True
# 179 average_pooling2d_8 True
# 180 average_pooling2d_9 True
# 181 activation_20 True
# 182 activation_22 True
# 183 conv_pad_10_1 True
# 184 conv_pad_10_2 True
# 185 conv_dw_10_1 True
# 186 conv_dw_10_2 True
# 187 conv_dw_10_1_bn True
# 188 conv_dw_10_2_bn True
# 189 conv_dw_10_1_Prelu True
# 190 conv_dw_10_2_Prelu True
# 191 conv_pw_10_1 True
# 192 conv_pw_10_2 True
# 193 conv_pw_10_1_bn True
# 194 conv_pw_10_2_bn True
# 195 conv_pw_10_1_relu True
# 196 conv_pw_10_2_relu True
# 197 s2_block_10_1 True
# 198 s2_block_10_2 True
# 199 batch_normalization_8 True
# 200 batch_normalization_9 True
# 201 activation_21 True
# 202 activation_23 True
# 203 concatenate_4 True
# 204 add_4 True
# 205 p_re_lu_4 True
# 206 conv_11 True
# 207 conv_11_bn True
# 208 conv_11_act True
# 209 average_pooling2d_10 True
# 210 average_pooling2d_11 True
# 211 activation_24 True
# 212 activation_26 True
# 213 conv_pad_11_1 True
# 214 conv_pad_11_2 True
# 215 conv_dw_11_1 True
# 216 conv_dw_11_2 True
# 217 conv_dw_11_1_bn True
# 218 conv_dw_11_2_bn True
# 219 conv_dw_11_1_Prelu True
# 220 conv_dw_11_2_Prelu True
# 221 conv_pw_11_1 True
# 222 conv_pw_11_2 True
# 223 conv_pw_11_1_bn True
# 224 conv_pw_11_2_bn True
# 225 conv_pw_11_1_relu True
# 226 conv_pw_11_2_relu True
# 227 s2_block_11_1 True
# 228 s2_block_11_2 True
# 229 batch_normalization_10 True
# 230 batch_normalization_11 True
# 231 activation_25 True
# 232 activation_27 True
# 233 concatenate_5 True
# 234 add_5 True
# 235 p_re_lu_5 True
# 236 conv_12 True
# 237 conv_12_bn True
# 238 conv_12_act True
# 239 average_pooling2d_12 True
# 240 average_pooling2d_13 True
# 241 activation_28 True
# 242 activation_30 True
# 243 conv_pad_12_1 True
# 244 conv_pad_12_2 True
# 245 conv_dw_12_1 True
# 246 conv_dw_12_2 True
# 247 conv_dw_12_1_bn True
# 248 conv_dw_12_2_bn True
# 249 conv_dw_12_1_Prelu True
# 250 conv_dw_12_2_Prelu True
# 251 conv_pw_12_1 True
# 252 conv_pw_12_2 True
# 253 conv_pw_12_1_bn True
# 254 conv_pw_12_2_bn True
# 255 conv_pw_12_1_relu True
# 256 conv_pw_12_2_relu True
# 257 s2_block_12_1 True
# 258 s2_block_12_2 True
# 259 batch_normalization_12 True
# 260 batch_normalization_13 True
# 261 activation_29 True
# 262 activation_31 True
# 263 concatenate_6 True
# 264 add_6 True
# 265 p_re_lu_6 True
# 266 conv_13 True
# 267 conv_13_bn True
# 268 conv_13_act True
# 269 average_pooling2d_14 True
# 270 average_pooling2d_15 True
# 271 activation_32 True
# 272 activation_34 True
# 273 conv_pad_13_1 True
# 274 conv_pad_13_2 True
# 275 conv_dw_13_1 True
# 276 conv_dw_13_2 True
# 277 conv_dw_13_1_bn True
# 278 conv_dw_13_2_bn True
# 279 conv_dw_13_1_Prelu True
# 280 conv_dw_13_2_Prelu True
# 281 conv_pw_13_1 True
# 282 conv_pw_13_2 True
# 283 conv_pw_13_1_bn True
# 284 conv_pw_13_2_bn True
# 285 conv_pw_13_1_relu True
# 286 conv_pw_13_2_relu True
# 287 s2_block_13_1 True
# 288 s2_block_13_2 True
# 289 batch_normalization_14 True
# 290 batch_normalization_15 True
# 291 activation_33 True
# 292 activation_35 True
# 293 concatenate_7 True
# 294 add_7 True
# 295 p_re_lu_7 True
# 296 conv_14 True
# 297 conv_14_bn True
# 298 conv_14_act True
# 299 average_pooling2d_16 True
# 300 average_pooling2d_17 True
# 301 activation_36 True
# 302 activation_38 True
# 303 conv_pad_14_1 True
# 304 conv_pad_14_2 True
# 305 conv_dw_14_1 True
# 306 conv_dw_14_2 True
# 307 conv_dw_14_1_bn True
# 308 conv_dw_14_2_bn True
# 309 conv_dw_14_1_Prelu True
# 310 conv_dw_14_2_Prelu True
# 311 conv_pw_14_1 True
# 312 conv_pw_14_2 True
# 313 conv_pw_14_1_bn True
# 314 conv_pw_14_2_bn True
# 315 conv_pw_14_1_relu True
# 316 conv_pw_14_2_relu True
# 317 s2_block_14_1 True
# 318 s2_block_14_2 True
# 319 batch_normalization_16 True
# 320 batch_normalization_17 True
# 321 activation_37 True
# 322 activation_39 True
# 323 concatenate_8 True
# 324 add_8 True
# 325 p_re_lu_8 True
# 326 conv_15 True
# 327 conv_15_bn True
# 328 conv_15_act True
# 329 average_pooling2d_18 True
# 330 average_pooling2d_19 True
# 331 activation_40 True
# 332 activation_42 True
# 333 conv_pad_15_1 True
# 334 conv_pad_15_2 True
# 335 conv_dw_15_1 True
# 336 conv_dw_15_2 True
# 337 conv_dw_15_1_bn True
# 338 conv_dw_15_2_bn True
# 339 conv_dw_15_1_Prelu True
# 340 conv_dw_15_2_Prelu True
# 341 conv_pw_15_1 True
# 342 conv_pw_15_2 True
# 343 conv_pw_15_1_bn True
# 344 conv_pw_15_2_bn True
# 345 conv_pw_15_1_relu True
# 346 conv_pw_15_2_relu True
# 347 s2_block_15_1 True
# 348 s2_block_15_2 True
# 349 batch_normalization_18 True
# 350 batch_normalization_19 True
# 351 activation_41 True
# 352 activation_43 True
# 353 concatenate_9 True
# 354 add_9 True
# 355 p_re_lu_9 True
# 356 concat_16_7 True
# 357 activation_44 True
# 358 conv_pw_16 True
# 359 conv_pw_16_bn True
# 360 conv_pw_16_relu True
# 361 activation_45 True
# 362 up_sampling2d False
# 363 batch_normalization_20 False
# 364 conv_pw_18 False
# 365 activation_46 False
# 366 conv_pw_18_bn False
# 367 tf_op_layer_Max False
# 368 conv_pw_18_relu False
# 369 information_blocking_decoder False
# 370 multiply False
# 371 activation_47 False
# 372 add_10 False
# 373 activation_48 False
# 374 up_sampling2d_1 False
# 375 batch_normalization_21 False
# 376 activation_49 False
# 377 conv_19 False
# 378 conv_19_bn False
# 379 conv_19_act False
# 380 up_sampling2d_2 False
# 381 batch_normalization_22 False
# 382 activation_50 False
# 383 reshape False
# 384 activation_51 False

# %%
model.load_weights("trained_weight/best_weights_4.h5")

# %%
# !rm -rf "trained_weight/best_weights.h5"

# %%
K.set_value(model.optimizer.lr, 5e-5)

# %%
INIT_LR = 5e-5

def poly_decay(epoch):
    maxEpochs = 600
    baseLR = INIT_LR
    power = 1.0
    alpha = baseLR * (1 - (epoch / float(maxEpochs))) ** power
    return alpha

# %%
H = model.fit_generator(train_datagen.generate(),
                        epochs=600,
                        steps_per_epoch=train_datagen.get_n_examples() // train_datagen.batch_size,
                        validation_data=val_datagen.generate(),
                        validation_steps=val_datagen.get_n_examples() // val_datagen.batch_size,
                        callbacks=[checkpoints, LearningRateScheduler(poly_decay)],
                        initial_epoch=319
                        )
# Out:
# Epoch 320/600
# 423/423 [==============================] - ETA: 0s - loss: 8.3394 - accuracy: 0.9724
# Epoch 00320: val_loss did not improve from 10.24319
# 423/423 [==============================] - 203s 480ms/step - loss: 8.3394 - accuracy: 0.9724 - val_loss: nan - val_accuracy: 0.9551 - lr: 2.3417e-05
# Epoch 321/600
# 423/423 [==============================] - ETA: 0s - loss: 8.3478 - accuracy: 0.9725
# Epoch 00321: val_loss did not improve from 10.24319
# 423/423 [==============================] - 203s 479ms/step - loss: 8.
600
# 423/423 [==============================] - ETA: 0s - loss: 8.3095 - accuracy: 0.9734
# Epoch 00591: val_loss did not improve from 9.95769
# 423/423 [==============================] - 200s 472ms/step - loss: 8.3095 - accuracy: 0.9734 - val_loss: 10.3096 - val_accuracy: 0.9574 - lr: 8.3333e-07
# Epoch 592/600
# 423/423 [==============================] - ETA: 0s - loss: 8.3333 - accuracy: 0.9727
# Epoch 00592: val_loss did not improve from 9.95769
# 423/423 [==============================] - 202s 478ms/step - loss: 8.3333 - accuracy: 0.9727 - val_loss: nan - val_accuracy: 0.9570 - lr: 7.5000e-07
# Epoch 593/600
# 423/423 [==============================] - ETA: 0s - loss: 8.3437 - accuracy: 0.9729
# Epoch 00593: val_loss did not improve from 9.95769
# 423/423 [==============================] - 206s 486ms/step - loss: 8.3437 - accuracy: 0.9729 - val_loss: 10.3361 - val_accuracy: 0.9563 - lr: 6.6667e-07
# Epoch 594/600
# 423/423 [==============================] - ETA: 0s - loss: 8.3188 - accuracy: 0.9729
# Epoch 00594: val_loss did not improve from 9.95769
# 423/423 [==============================] - 203s 479ms/step - loss: 8.3188 - accuracy: 0.9729 - val_loss: nan - val_accuracy: 0.9586 - lr: 5.8333e-07
# Epoch 595/600
# 423/423 [==============================] - ETA: 0s - loss: 8.3395 - accuracy: 0.9731
# Epoch 00595: val_loss did not improve from 9.95769
# 423/423 [==============================] - 202s 478ms/step - loss: 8.3395 - accuracy: 0.9731 - val_loss: nan - val_accuracy: 0.9561 - lr: 5.0000e-07
# Epoch 596/600
# 423/423 [==============================] - ETA: 0s - loss: 8.3497 - accuracy: 0.9730
# Epoch 00596: val_loss did not improve from 9.95769
# 423/423 [==============================] - 199s 470ms/step - loss: 8.3497 - accuracy: 0.9730 - val_loss: nan - val_accuracy: 0.9564 - lr: 4.1667e-07
# Epoch 597/600
# 423/423 [==============================] - ETA: 0s - loss: 8.3337 - accuracy: 0.9727
# Epoch 00597: val_loss did not improve from 9.95769
# 423/423 [==============================] - 198s 468ms/step - loss: 8.3337 - accuracy: 0.9727 - val_loss: nan - val_accuracy: 0.9569 - lr: 3.3333e-07
# Epoch 598/600
# 423/423 [==============================] - ETA: 0s - loss: 8.3310 - accuracy: 0.9729
# Epoch 00598: val_loss did not improve from 9.95769
# 423/423 [==============================] - 197s 466ms/step - loss: 8.3310 - accuracy: 0.9729 - val_loss: 10.2247 - val_accuracy: 0.9583 - lr: 2.5000e-07
# Epoch 599/600
# 423/423 [==============================] - ETA: 0s - loss: 8.3298 - accuracy: 0.9726
# Epoch 00599: val_loss did not improve from 9.95769
# 423/423 [==============================] - 198s 469ms/step - loss: 8.3298 - accuracy: 0.9726 - val_loss: nan - val_accuracy: 0.9563 - lr: 1.6667e-07
# Epoch 600/600
# 423/423 [==============================] - ETA: 0s - loss: 8.3305 - accuracy: 0.9728
# Epoch 00600: val_loss did not improve from 9.95769
# 423/423 [==============================] - 199s 471ms/step - loss: 8.3305 - accuracy: 0.9728 - val_loss: nan - val_accuracy: 0.9580 - lr: 8.3333e-08

# %%
K.get_value(model.optimizer.lr)
# Out:
# 8.333333e-08

# %% [markdown]
# ## Predictions

# %%
model.load_weights("trained_weight/best_weights_4_all.h5")

# %%
def predict():
    idx = np.random.choice(val_datagen.get_n_examples(), 1)[0]
    img_path = val_datagen.image_paths[idx]
    label_path = val_datagen.label_paths[idx]
    
    preprocessors = [val_datagen.resize_img, val_datagen.mean_substraction]
    img_origin = val_datagen.load_image(img_path)
    img_resize = cv2.resize(img_origin, (224, 224))[..., ::-1]
    label = val_datagen.load_image(label_path)
    label = val_datagen.resize_img(label, interpolation=cv2.INTER_NEAREST)
    img_preprocess = val_datagen.preprocessing(img_origin, preprocessors=preprocessors)
    img = np.expand_dims(img_preprocess, axis=0)
    
    prediction = model.predict(img)
    prediction = prediction[0]
    mask = np.reshape(prediction, (IMG_HEIGHT, IMG_WIDTH, N_CLASSES))
    mask = np.argmax(mask, axis=-1)
    mask[mask > 0] = 255
    
    new_img = np.copy(img_resize)
    non_zeros_idx = np.where(mask == 0)
#     non_zeros_idx = np.nonzero()
    new_img[..., 0][non_zeros_idx] = 0
    new_img[..., 1][non_zeros_idx] = 0
    new_img[..., 2][non_zeros_idx] = 0
    
#     print(mask)
#     for i in range(N_CLASSES):
#     class_idx = prediction.argmax(axis=-1)
    mask = cv2.merge([mask, mask, mask])
    
    img_resize = cv2.resize(img_resize, (512, 512))
    new_img = cv2.resize(new_img, (512, 512))
    
    ia.imshow(np.hstack([
        img_resize,
        new_img
    ]))

# %%
predict()

# %% [markdown]
# ## Evaluation

# %%
eg1800_dir = "Portrait/"
eg1800_val_anno_path = "Portrait/EG1800_val.txt"
eg1800_train_anno_path = "Portrait/EG1800_train.txt"

# %%
def load_image_paths(anno_paths, input_dir, target_dir, task="train"):
    image_paths = []
    label_paths = []

    for anno_path in anno_paths:
        anno_dir = os.path.dirname(anno_path)
        df_file_names = pd.read_csv(anno_path, header=None)
        file_names = df_file_names[0].values
        
        for fn in file_names:
#             if task == "train":
#                 fn = format(fn, "05d") + ".jpg"
#             else:
#                 fn = format(fn, "05d") + "_mask.png"
#             if "DS_Store" in fn: continue
            img_train_dir = os.path.join(anno_dir, input_dir)
            img_label_dir = os.path.join(anno_dir, target_dir)
            img_train_path = os.path.join(img_train_dir, format(fn, "05d") + ".jpg")
            img_label_path = os.path.join(img_label_dir, format(fn, "05d") + "_mask.png")

            image_paths.append(img_train_path)
            label_paths.append(img_label_path)

    image_paths = np.array(image_paths)
    label_paths = np.array(label_paths)

    return image_paths, label_paths

# %%
test_img_paths, test_lbl_paths = load_image_paths([eg1800_val_anno_path], "images_data_crop", "GT_png")

# %%
test_img_paths
# Out:
# array(['Portrait/images_data_crop/00002.jpg',
#        'Portrait/images_data_crop/00005.jpg',
#        'Portrait/images_data_crop/00008.jpg',
#        'Portrait/images_data_crop/00011.jpg',
#        'Portrait/images_data_crop/00012.jpg',
#        'Portrait/images_data_crop/00014.jpg',
#        'Portrait/images_data_crop/00016.jpg',
#        'Portrait/images_data_crop/00024.jpg',
#        'Portrait/images_data_crop/00037.jpg',
#        'Portrait/images_data_crop/00040.jpg',
#        'Portrait/images_data_crop/00044.jpg',
#        'Portrait/images_data_crop/00059.jpg',
#        'Portrait/images_data_crop/00061.jpg',
#        'Portrait/images_data_crop/00062.jpg',
#        'Portrait/images_data_crop/00064.jpg',
#        'Portrait/images_data_crop/00065.jpg',
#        'Portrait/images_data_crop/00073.jpg',
#        'Portrait/images_data_crop/00075.jpg',
#        'Portrait/images_data_crop/00076.jpg',
#        'Portrait/images_data_crop/00079.jpg',
#        'Portrait/images_data_crop/00080.jpg',
#        'Portrait/images_data_crop/00083.jpg',
#        'Portrait/images_data_crop/00085.jpg',
#        'Portrait/images_data_crop/00093.jpg',
#        'Portrait/images_data_crop/00094.jpg',
#        'Portrait/images_data_crop/00096.jpg',
#        'Portrait/images_data_crop/00107.jpg',
#        'Portrait/images_data_crop/01056.jpg',
#        'Portrait/images_data_crop/01061.jpg',
#        'Portrait/images_data_crop/01068.jpg',
#        'Portrait/images_data_crop/01071.jpg',
#        'Portrait/images_data_crop/01083.jpg',
#        'Portrait/images_data_crop/01087.jpg',
#        'Portrait/images_data_crop/01096.jpg',
#        'Portrait/images_data_crop/01100.jpg',
#        'Portrait/images_data_crop/01104.jpg',
#        'Portrait/images_data_crop/01105.jpg',
#        'Portrait/images_data_crop/01110.jpg',
#        'Portrait/images_data_crop/01111.jpg',
#        'Portrait/images_data_crop/01112.jpg',
#        'Portrait/images_data_crop/01118.jpg',
#        'Portrait/images_data_crop/01129.jpg',
#        'Portrait/images_data_crop/01139.jpg',
#        'Portrait/images_data_crop/01148.jpg',
#        'Portrait/images_data_crop/01149.jpg',
#        'Portrait/images_data_crop/01150.jpg',
#        'Portrait/images_data_crop/01151.jpg',
#        'Portrait/images_data_crop/01167.jpg',
#        'Portrait/images_data_crop/01168.jpg',
#        'Portrait/images_data_crop/01175.jpg',
#        'Portrait/images_data_crop/01178.jpg',
#        'Portrait/images_data_crop/01179.jpg',
#        'Portrait/images_data_crop/01184.jpg',
#        'Portrait/images_data_crop/01186.jpg',
#        'Portrait/images_data_crop/01196.jpg',
#        'Portrait/images_data_crop/01214.jpg',
#        'Portrait/images_data_crop/01215.jpg',
#        'Portrait/images_data_crop/01216.jpg',
#        'Portrait/images_data_crop/01219.jpg',
#        'Portrait/images_data_crop/01220.jpg',
#        'Portrait/images_data_crop/01225.jpg',
#        'Portrait/images_data_crop/01226.jpg',
#        'Portrait/images_data_crop/01227.jpg',
#        'Portrait/images_data_crop/01232.jpg',
#        'Portrait/images_data_crop/01234.jpg',
#        'Portrait/images_data_crop/01235.jpg',
#        'Portrait/images_data_crop/01236.jpg',
#        'Portrait/images_data_crop/01240.jpg',
#        'Portrait/images_data_crop/01255.jpg'], dtype='<U35')

# %%
test_images = val_datagen.load_images(test_img_paths)

# %%
test_images.shape
# Out:
# (270, 224, 224, 3)

# %%
test_labels = val_datagen.load_labels(test_lbl_paths)

# %%
test_labels.shape
# Out:
# (270, 50176, 2)

# %%
predictions = model.predict(test_images, batch_size=24)

# %%
predictions = np.argmax(predictions, axis=-1)

# %%
# predictions = np.expand_dims(predictions, axis=-1)

# %%
predictions.shape
# Out:
# (270, 50176)

# %%
def iou(label, prediction):
    non_indices_label = np.nonzero(label)[0]
    non_indices_prec = np.nonzero(prediction)[0]
    
    TP = 0
    FP = 0
    
    for i in non_indices_prec:
        if i in non_indices_label: 
            TP += 1
        else: 
            FP += 1
            
    for i in non_indices_label:
        if i not in non_indices_prec:
            FP += 1
    
    if TP + FP == 0:
        return 0
    
    return float(TP/(TP+FP))

# %%
iou(test_labels[0][..., 1], predictions[0])
# Out:
# 0.8350863326848249

# %%
def miou(labels, predictions):
    miou = 0
    
    for i in range(len(labels)):
        miou += iou(labels[i][..., 1], predictions[i])
    
    return float(miou/len(predictions))

# %%
miou(test_labels, predictions)
# Out:
# 0.9147264011187503
